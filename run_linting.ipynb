# %%
import os
import json
import subprocess
from tqdm import tqdm
import sys
import re

# %% [markdown]
# ### Loading path so that the installed apps work

# %%
env = os.environ.copy()
env["PATH"] = "/home/pooria/.nvm/versions/node/v22.17.1/bin:" + env["PATH"]
env["PATH"] = os.path.expanduser("~/.dotnet/tools") + ":" + env["PATH"]

subprocess.run(["dotnet-script", "--version"], env=env)
# Out:
# 1.6.0
# CompletedProcess(args=['dotnet-script', '--version'], returncode=0)

# %% [markdown]
# ### Python

# %%
import py_compile

directory = "files/python/codes/"
output_file = "results/python_lint.json"
all_results = []

py_files = [f for f in os.listdir(directory) if f.endswith(".py")]
os.makedirs(os.path.dirname(output_file), exist_ok=True)

# Disable .pyc creation globally
sys.dont_write_bytecode = True

for filename in tqdm(py_files, desc="Linting files", unit="file"):
    filepath = os.path.join(directory, filename)

    try:
        # Compile with syntax check, no .pyc files written
        py_compile.compile(filepath, doraise=True)
    except py_compile.PyCompileError as e:
        err = {
            "type": "syntax-error",
            "module": filename,
            "obj": "",
            "line": getattr(e.exc_value, "lineno", None),
            "column": None,
            "path": filepath,
            "symbol": "syntax-error",
            "message": str(e.exc_value),
            "message-id": ""
        }
        all_results.append(err)

# Write all results to JSON once after all files are processed
with open(output_file, "w") as f:
    json.dump(all_results, f, indent=2)
# Out:
# Linting files:   0%|          | 0/57371 [00:00<?, ?file/s]
# Linting files:   6%|▌         | 3513/57371 [00:00<00:07, 6860.67file/s]files/python/codes/f9020fb7333512648836226a2ffdd74b_1.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   100 is larger
# files/python/codes/4e571d4ed1051f5093aa8dba0b93bd16_0.py:3: SyntaxWarning: 'ellipsis' object is not callable; perhaps you missed a comma?
#   ...
# files/python/codes/4e571d4ed1051f5093aa8dba0b93bd16_1.py:2: SyntaxWarning: 'ellipsis' object is not callable; perhaps you missed a comma?
#   ...
# Linting files:  44%|████▎     | 25017/57371 [00:00<00:00, 75449.02file/s]files/python/codes/f9020fb7333512648836226a2ffdd74b_3.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   100 is larger
# files/python/codes/4c6e8408688326f9461d2bbd42ffc8f7_5.py:1: SyntaxWarning: 'list' object is not callable; perhaps you missed a comma?
#   [License](LICENSE)
# Linting files:  67%|██████▋   | 38265/57371 [00:03<00:02, 7453.20file/s] files/python/codes/3cdfd066511fc2a41166a14f4fd2c3a3_1.py:1: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   [['1' '2' '3']
# Linting files:  98%|█████████▊| 56169/57371 [00:06<00:00, 7218.17file/s]files/python/codes/d81126efa156ae1358a57a6af782e99d_1.py:3: SyntaxWarning: 'ellipsis' object is not callable; perhaps you missed a comma?
#   ...
# Linting files:  99%|█████████▉| 56946/57371 [00:06<00:00, 7177.48file/s]files/python/codes/3554f1851ac95a292b59b51145ef8ad0_0.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   warning: 'PyUnicode_FromUnicode' is deprecated [-Wdeprecated-declarations]
# Linting files: 100%|██████████| 57371/57371 [00:06<00:00, 9055.38file/s]

# %% [markdown]
# ### Javascript
# Make sure you have eslint installed

# %%
import os
import json
import subprocess

directory = "files/javascript/codes/"
output_file = "results/js_lint.json"
os.makedirs(os.path.dirname(output_file), exist_ok=True)

js_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith(".js")]
all_results = []


# Batch size (tweak if needed)
BATCH_SIZE = 20000  

def run_eslint_batch(batch_files):
    result = subprocess.run(
        [
            "eslint",
            "--config",
            "linting_rules/js.eslint.config.mjs",
            "--format",
            "json",
            *batch_files,
        ],
        capture_output=True,
        text=True,
        env=env,
    )
    try:
        return json.loads(result.stdout)
    except json.JSONDecodeError:
        print("⚠️ Failed to parse JSON from ESLint output:")
        print(result.stdout)
        return []

# Run in batches
for i in range(0, len(js_files), BATCH_SIZE):
    batch = js_files[i:i + BATCH_SIZE]
    file_results = run_eslint_batch(batch)

    for file_result in file_results:
        filename = os.path.basename(file_result.get("filePath", ""))
        for msg in file_result.get("messages", []):
            if msg.get("fatal", False) or msg.get("severity", 0) == 2:
                all_results.append({
                    "type": "syntax-error",
                    "module": filename,
                    "obj": "",
                    "line": msg.get("line"),
                    "column": msg.get("column"),
                    "path": file_result.get("filePath"),
                    "symbol": "syntax-error",
                    "message": msg.get("message", ""),
                    "message-id": "",
                })

# Save results
with open(output_file, "w") as f:
    json.dump(all_results, f, indent=2)

print(f"✅ Linting complete, results saved to {output_file}")
# Out:
# ✅ Linting complete, results saved to results/js_lint.json

# %% [markdown]
# ### Java files

# %%
# !sudo apt install default-jdk
# Out:
# [sudo] password for pooria:

# %%
import shutil
import hashlib

directory = "files/java/codes/"
good_dir = os.path.join(directory, "good")
os.makedirs(good_dir, exist_ok=True)

java_files = [f for f in os.listdir(directory) if f.endswith(".java")]
public_class_pattern = re.compile(r'public\s+class\s+(\w+)')

# Map from hash (hex string) to original filename
mapping = {}

def hash_file_content(path):
    hasher = hashlib.sha256()
    with open(path, "rb") as f:
        while chunk := f.read(8192):
            hasher.update(chunk)
    return hasher.hexdigest()

for filename in java_files:
    filepath = os.path.join(directory, filename)
    with open(filepath, "r", encoding="utf-8") as f:
        content = f.read()

    # Find public class name
    match = public_class_pattern.search(content)
    if match:
        class_name = match.group(1)
        file_hash = hash_file_content(filepath)

        new_filename = f"{class_name}.java"
        dest_path = os.path.join(good_dir, new_filename)

        if os.path.exists(dest_path):
            continue
        else:
            print(f"Copying {filename} → good/{new_filename}")
            shutil.copy2(filepath, dest_path)

        # Map hash → original filename
        mapping[file_hash] = filename
# Out:
# Copying ab09eef5d14bac1a1ff761a7d77a07c1_0.java → good/QuizController.java
# Copying 14e324436caad13d217bcb7b723c9175_9.java → good/User.java
# Copying 1c3767860affeb923a9736d2fe92bedd_0.java → good/DisableRegenPlugin.java
# Copying b51cc1f10724c38f41cb7d37f387e510_1.java → good/KnnSignalHistoryService.java
# Copying 0b27669ed4aa5db14236d8c006f35bac_13.java → good/CustomDolphins.java
# Copying 0d22d7a849fdc87fdccaca6bd3c8b62d_5.java → good/AccountBalanceException.java
# Copying 2f61ab105239df7ef679fd295e7ed4f0_14.java → good/UserServiceImpl.java
# Copying 3ca0eb685fc71a09183130dd110791d6_1.java → good/SentryInitializer.java
# Copying 4510cc13d09d846c6561f8adf93ea0f2_3.java → good/DatabaseManager.java
# Copying 9b702073976e1f60611ff4cb8b5b5ee8_2.java → good/UIAnotherScreen.java
# Copying d5ffdf695700932a7fc001e2ca23e312_50.java → good/InfluxDBService.java
# Copying 1946f8753e9eaed67feba2259cf19a42_3.java → good/MyDateUtil.java
# Copying 315a2ecee52cb495c531573c1435a9f0_5.java → good/LocatingCustomElementHandler.java
# Copying 6ead9e47c888aebba7f267a541273c93_3.java → good/Role.java
# Copying ac62baf0da2de4c05da374fc648651b3_10.java → good/Traversal.java
# Copying eac8e110d312edd286f3986189d31367_7.java → good/TaskPoint.java
# Copying 14f8ee4888c9c788856ec604221667b5_14.java → good/Datos.java
# Copying d388c5a46e051f5521f285891e55dfde_2.java → good/Bicycle.java
# Copying 3c9315f465e1640c7c47b1162c4fb49d_1.java → good/DisplayListener.java
# Copying f934b413257e52ace9066adea3c54b3b_5.java → good/Usuario.java
# Copying b78c2a2c0d2e0003b47bd26737502740_0.java → good/RingBuffer.java
# Copying 0fe8382e895ab6b26f8dff2fe91e5db4_11.java → good/ChannelGroupManager.java
# Copying d46b9bb913e6eef876d2e39915d15d45_1.java → good/WelcomeServlet.java
# Copying 8f8e892241dcdceb15633b539d286f3b_1.java → good/ScoreboardUtil.java
# Copying d578616152e1f877fc84909163b87d49_7.java → good/Adult.java
# Copying 78f66b5b0b14c505009d991bf1bd2b53_16.java → good/SSLClientSingleton.java
# Copying 66736891a54d469e037f905ec0bf5f48_8.java → good/HttpHandshakeInterceptor.java
# Copying ea0429d394f5d10a359b7cf5eaf27f0f_0.java → good/CacheServiceTest.java
# Copying 13f6338972576eb86a838c5bab790a66_11.java → good/RateLimiterConfig.java
# Copying 27887c7a23ebced5f534de70dcf5502b_6.java → good/UtilidadesTest.java
# Copying fdb0276bd395a1d66ac63a503af64ffe_1.java → good/VentaComputadorasTest.java
# Copying be34178fb2d0edf798d056ad969619ec_7.java → good/MyItemProcessor.java
# Copying 99fdd525f20616ecd0d2ac4b99b49d9d_6.java → good/JwtTokenUtil.java
# Copying bdf2ad4f33069c72be28e72be86e3f9f_0.java → good/Singleton.java
# Copying 01a1625d5cbd4c7f182afc48ea7a8b8a_8.java → good/ManejadorMenu.java
# Copying da3b8ce6b7de1ad0e495b6c7422048e3_1.java → good/SecurityConfig.java
# Copying a9ba2059dabb805db0920b58e69ff534_0.java → good/Account.java
# Copying 3e6f971b1ba80ebc8fade55a10c4eca3_0.java → good/Post.java
# Copying c40e5727676d1a8f06194eea28d47579_4.java → good/ConnexionMySQL.java
# Copying d5a26359e35ef21dccd1c230696877d5_0.java → good/Magpie.java
# Copying 247f6691e96cd671bdb2cc115189914e_2.java → good/Worker.java
# Copying 90b71762ca1f8a7a77149fbb2b173ae7_0.java → good/MockClass.java
# Copying 17c5ef6ba1476aee69355ea5c42f4e17_0.java → good/LogbackUncaughtExceptionHandler.java
# Copying eda1f38d9fd59aebef8b6221c9c39808_9.java → good/Libros.java
# Copying c1b3bd0a81593d41c85d24c2949f8670_12.java → good/PedidosServlet.java
# Copying ce4eb5348b6015b6f8437555a5a0c22a_0.java → good/CustomRenderer.java
# Copying 33d383f1a73c26031a4e30a3ce638f2d_2.java → good/S3Config.java
# Copying 93d5dffded915d20b4601525e692c7c0_2.java → good/MainActivity.java
# Copying d70a8478492af09450a739fc1a61402f_0.java → good/MyListener.java
# Copying 62fde6b4e2d874d2c3170eb07c179c18_6.java → good/YourClass.java
# Copying e5fa30e3e29acae8b1b56eefa9af16c5_3.java → good/Appliance.java
# Copying d5e75c0bb4367d08ac65dfb61c02c521_2.java → good/CareerService.java
# Copying 7da4acc7d122e87bc36b01ad76c4e92b_10.java → good/Product.java
# Copying e4c62bff3efbd680282016c58cd2f0a7_1.java → good/MatcherExample.java
# Copying 9f64372e590fcf117ae0cd4c4257193f_0.java → good/Spawner.java
# Copying c446f65e349b6af7bdb3c3557df50dbd_7.java → good/RequestQueue.java
# Copying ce348a96387462ab3b2e6501e03a3436_3.java → good/FirebaseAuthUtil.java
# Copying 3b9881963a95d533ca7c014f99d26b42_9.java → good/CustomUserDetailsService.java
# Copying 8a2a0d4f0e27b2557eb0fef050f134c0_0.java → good/ClassesInstancesObjects.java
# Copying 6a48daad34d255702cff4f4eeaaec2af_0.java → good/UserDAO.java
# Copying 8c996a502b3f9484d84bb5a9649a949d_6.java → good/PeliculaVO.java
# Copying 9d5024333cd72db412cebe3797864ef8_0.java → good/PartnersNumberUpdateFacadeServiceTest.java
# Copying 2d9d9454fa349f53db0977f5047371e8_1.java → good/MyTest.java
# Copying 4a5b82babb82b5fe3f8a966f852eeaca_9.java → good/UserItem.java
# Copying e543d4261299cc693378a104da46db5b_3.java → good/MyConfig.java
# Copying 99f8b32c2255da728899774f92de35ac_1.java → good/VueClient.java
# Copying 576dd8afd09f4d4e979bb3cefe548445_1.java → good/MyJavaFXApp.java
# Copying dcb5c7904d713c9a3cb81b4dd0af651e_21.java → good/LoginRequest.java
# Copying 26992a35877bbb57d0b31151eca1820e_0.java → good/MyApplicationRunner.java
# Copying bc15725abe41a950f5d6934537eac3b1_1.java → good/SNSClient.java
# Copying 2f7798a6f02d63e77941883f59bc73d5_0.java → good/KafkaBatchWriter.java
# Copying 032bd6a2408052f9c2c3733e86b9d8ad_1.java → good/ParentEntity.java
# Copying b929cb8ae13033543c1b331c1b55fb7e_5.java → good/Task.java
# Copying b728b15bf99f1ff5c73c695cce412da7_3.java → good/MinioConfig.java
# Copying 10013f0ffbdf5db99334620eee07e47f_5.java → good/MyResponseBody.java
# Copying 5d3a9fcd1dc9acb25bef51f176abccf2_2.java → good/AppUserServiceImpl.java
# Copying 8657d3995a96f83d164e2fd6c68b182d_0.java → good/Example.java
# Copying be1e45d529584c2966e6a4f26c78c246_7.java → good/NoteViewModel.java
# Copying 0d1ccc2bdc9c68ed4f51beecc3289592_0.java → good/CardAttribute.java
# Copying 450a696f7a3180ad652d0a7dbdae661a_1.java → good/PaymentInfo.java
# Copying 80c4756a11c8bc711315b35ef0308138_0.java → good/ListaEstudiantes.java
# Copying 215723b525c319c81658877ae1a346b2_1.java → good/MiClaseConLogin.java
# Copying 31b596d572057c69973c9329316c05e2_7.java → good/UserController.java
# Copying 815cdfe733a8fa672d223b7469ed708d_6.java → good/MyController.java
# Copying 21ca2826be1255087cc73899966caea2_7.java → good/MessageListenerImpl.java
# Copying ad89b6a3e3f454b09a4fb17b6c05bfc8_7.java → good/ObjectBDaoImpl.java
# Copying def039021f4f1f2bb17087b00d745e35_0.java → good/HelloWorld.java
# Copying 3c9a7338549b3bab2243647be588cdf0_3.java → good/AllConditionHandler.java
# Copying 9e4ed1e141d6559d7f26a33062b386a6_2.java → good/ImageAdapter.java
# Copying b1de3634c8b3d845f746d4543b9204b4_3.java → good/MyComponent.java
# Copying d211bb8ae90fc504b34f6dfd0199750e_8.java → good/StateMachineConfig.java
# Copying 72d923f29ceff553d4e0786a5a1c14a4_0.java → good/BoardManager.java
# Copying d88bf98fbf40a79073d9555bca46aa57_26.java → good/GlobalExceptionHandler.java
# Copying 9d836304fbc5bf3c8dbc593e99ae5652_1.java → good/SwaggerConfig.java
# Copying 22ee3eb297f8d1624acd6524a9532803_1.java → good/MiCalendarioViewModel.java
# Copying f0f66344f5ae607ee17510222ba4bdf6_4.java → good/ElectricityRecord.java
# Copying a9fa0f8e0ce21271ada43f95fe6b3dc2_1.java → good/FhirController.java
# Copying 7aa87ed2c34855175973884c718eee97_4.java → good/PackOfCards.java
# Copying 0f290545e7f9a1ebc919d9047b240286_1.java → good/WebSocketConfig.java
# Copying 720ea8ad9889ee3a4b449f16672a2a74_1.java → good/ACR38Connector.java
# Copying 9735eaf2aea16e62317fd3c4a2402f28_2.java → good/Cafe.java
# Copying bc617634334079ce1b46b71e2bc5458c_5.java → good/Main.java
# Copying 286420a4a7f2cfe0bd0c965875dcb0c5_4.java → good/ApplicationConfig.java
# Copying a9a053f6ecaccac7f6c88b3014033eb9_2.java → good/CustomInvocationHandlerFactory.java
# Copying 21fdcb5cad0d3072c702f3519b02b807_4.java → good/YourObjectType.java
# Copying 0fa4a87d6ada432868d0a969cc8437e5_2.java → good/ProductController.java
# Copying 7e8ea875c4e1685905e5bb552f207ea1_5.java → good/GatewayConfiguration.java
# Copying 31df5f676924376cb0b3b9b23e841ea8_0.java → good/Order.java
# Copying 924b23d2fdc08865070f54776c6f3113_14.java → good/AlumnoService.java
# Copying 8576faf3e2e50d6beab87c8b88192bfb_16.java → good/RestExceptionHandler.java
# Copying d5ffdf695700932a7fc001e2ca23e312_28.java → good/DtoTransformationService.java
# Copying 6b78bde94c3afc48ff37e12b82b5493e_8.java → good/SuccessOnlyConsoleAppender.java
# Copying 6153c3a9decb8a6cda6c1528408e46e0_7.java → good/AbsDisposalService.java
# Copying 6daa5b68b3867c97c28be0cb7874284f_1.java → good/shape.java
# Copying 220cd3e27ee5ae6334be3424e9f92f33_1.java → good/CrowdPackSync2NascentEcrpServiceImpl.java
# Copying fec3b5a7c3adabe8d5af2e2e4a233488_1.java → good/Localization.java
# Copying 3e6154e505f871c4ba74d132e0ac5aef_4.java → good/Result.java
# Copying 1b3db17b93c9208dd6272cd55241f967_0.java → good/MyPreloader.java
# Copying 9fba8641ba39a9c2219f67a5bb727f08_0.java → good/LogoutServlet.java
# Copying 81cbaaa9b7597759573fa13d4154b28f_2.java → good/AdminService.java
# Copying 69169e60cb594ea2f5105b3ac2828a6f_8.java → good/CarOptionsFragment.java
# Copying 5937663fcdc3c65e2bc82e1fcb1845e4_2.java → good/ThreadPoolConfig.java
# Copying 064c68d283cb31939e17f6ad8d40bcb1_9.java → good/TicketingSystem.java
# Copying a73f555edfd39e1a200a14909eada85d_0.java → good/MyClass.java
# Copying 02b4de8b364274e1d3c2988d69b9ae06_1.java → good/MyAdapter.java
# Copying ea5c9224d75fec937c208b180204c03f_0.java → good/JPAUnitTestCase.java
# Copying 79cc7c9033e8702d5f08feea0ab36b1e_0.java → good/MyMessageListener.java
# Copying 8f71eb2db37aa92156414f47551921ef_4.java → good/Income.java
# Copying fbb8c692f78e858532be6e3d51999a0e_0.java → good/UpgradePlugin.java
# Copying 68ad126dc19e8c86020150852712a4c0_0.java → good/BooleanExpressionEvaluator.java
# Copying 51d10b96f69f1f18c7cbdb3869ea5379_1.java → good/EconomyManager.java
# Copying 4f2dcd3d7dba21ed910fa3500ea534a2_2.java → good/SampleController.java
# Copying 732888c53dda61b8603a5db56d542f10_4.java → good/School.java
# Copying 286420a4a7f2cfe0bd0c965875dcb0c5_6.java → good/SentryTransactionFilter.java
# Copying 03a98ecba64df4e04cde9f0c54019d62_3.java → good/ComputerDirector.java
# Copying 4c7abe893143fd226486c8fc82065fcc_16.java → good/Skin.java
# Copying 614b877245d6a71adedaff0a5744af3d_15.java → good/TreeNode.java
# Copying def039021f4f1f2bb17087b00d745e35_9.java → good/UserRepository.java
# Copying 09149fa7d52c000fe700e32a4b81d2cd_0.java → good/MyRecorder.java
# Copying b6571621f563da97be782353bff575b8_6.java → good/UnicomConfig.java
# Copying 06a4d069b10cff0b664cdb5f19912118_2.java → good/BossBarPluginManager.java
# Copying 70e0957358d1a8593a9a88880ecf476e_20.java → good/UserData.java
# Copying 3a5b291184181130937213ba1d551196_6.java → good/NativeWrapper.java
# Copying 6a2905c6eb032f4c7852f746d00e7942_2.java → good/AdminController.java
# Copying a594a39e5cdc57ae7ee0f21974915605_0.java → good/ClanPlugin.java
# Copying 8dd5b02cfa8b70f4657336bf96053fbe_18.java → good/SomeService.java
# Copying 019d8749b15dd6189f1e91262b13658d_0.java → good/MiningSimulatorPlugin.java
# Copying a71949dbc1eeff4a1a5c585435cd54f6_2.java → good/MenuService.java
# Copying 2a69dc92d45ed1176801bfec34474987_38.java → good/StringUtil.java
# Copying 60d0c43479a59306d57d8509ccd2c73c_3.java → good/SSD.java
# Copying 2d0d9b65d54b5b74a269c6bc042bdccf_9.java → good/TaxiInfoWritable.java
# Copying 1f1390e5ca0584e7f3f26d8e2b2eb2b4_3.java → good/UsuarioController.java
# Copying 7e0f282d44bb7ca4f07d384c7d10d785_0.java → good/Connection.java
# Copying 8ee491f05d97ce24f44e613b238c70ca_3.java → good/Contact.java
# Copying c6bf4fa6d710e7c485f3ae0b315173eb_4.java → good/LocalDateTimeWrapperTypeAdapter.java
# Copying aeef68159306ca843aeaf53ef52a3d63_0.java → good/CelularServlet.java
# Copying df16b67bd2890fe2fc92dc6967d54410_3.java → good/Dictionary.java
# Copying c8bf7f3664662dbb0c8a22dd95161712_2.java → good/WorldGenTransparentBlock.java
# Copying f82dea1ac9678a64a37978ce40331743_3.java → good/SortedLinkedList.java
# Copying 7c3849d84e0735de40104b43fb271be2_0.java → good/GetSome.java
# Copying f21ed63811d99ea48c1507574fc3820f_0.java → good/Hospital.java
# Copying 84cd2b5633413b645a78c21b59f0ea9c_2.java → good/AutocompleteController.java
# Copying 0cfca44fc0e408915a7f3910770af201_2.java → good/ApiResponse.java
# Copying 4f3f59f9365ebd54ef0cea23e701df39_16.java → good/UsuarioLogin.java
# Copying 8229935a975164de4ff31abd49cbb3cb_15.java → good/OrganizationController.java
# Copying 3bc88a0067cb5731ce110694e9f120c6_13.java → good/CustomEventListener.java
# Copying 7f88c4c6b16c7bbaf94a9205d2287222_0.java → good/RaycastController.java
# Copying b7c9a6fa89175c4550defc20d4274d4d_4.java → good/CharacterUI.java
# Copying 723cb5f61a41c354dfd2410bc66664ce_2.java → good/SecondFragment.java
# Copying 9931cd9cdfd699a8541d8a37e17b1ea8_3.java → good/PlayerQuitListener.java
# Copying 14f8ee4888c9c788856ec604221667b5_3.java → good/EstudiantesDataFactory.java
# Copying 2331084ee1929cfb1917c3dbb14d378c_14.java → good/MiClase.java
# Copying df17ff2689330a7c21227668939c3577_35.java → good/ProxyBeanRegistrar.java
# Copying f75068d352dc202fa9833bbaf8c7ee31_2.java → good/SentryPerformanceConfig.java
# Copying 255898b9509d0f392037c9986285eca9_21.java → good/AuthorizationServerConfiguration.java
# Copying 6a2905c6eb032f4c7852f746d00e7942_0.java → good/FoodMenu.java
# Copying c605b3fe90c5f2242d979db4dfaffac0_2.java → good/CustomDateDeserializer.java
# Copying 2ee3debcc43a49871ec011e390c03e83_2.java → good/XOGame.java
# Copying c61f2699b31063e059225bcf26e97705_0.java → good/CustomNamingStrategy.java
# Copying 06882404b7f259ba8fbbe41875ea5314_13.java → good/ResourceHelper.java
# Copying 01a1625d5cbd4c7f182afc48ea7a8b8a_4.java → good/MiActividad.java
# Copying c390ca55cae96ab82fdbc6a1c0874974_3.java → good/MyWebSocket.java
# Copying 4c26f2f5a2c6fba0d4b280a88d71b0d5_9.java → good/Weapon.java
# Copying c3455daa228f7947e26aa1b9ce1d2134_1.java → good/ExampleMod.java
# Copying 2324db535eec66c9279833f376ae0b2a_22.java → good/GrindableSurface.java
# Copying fd1e856570ba4d01b2e4a73a27e12ba9_0.java → good/Domino.java
# Copying 305fcdf260d789779b11b3b34508def4_3.java → good/Calculator.java
# Copying c5a9810db05a7796e4b93d7b8f176eca_1.java → good/ClassA.java
# Copying 8229d33676040b4d181dcef97222d0f5_9.java → good/SeleniumWorker.java
# Copying 79cc7c9033e8702d5f08feea0ab36b1e_8.java → good/DelayMessageListener.java
# Copying 85e675dfd6ddb0396c7c0a99509347ad_9.java → good/ChatApi.java
# Copying 28a06caddba9162f1ff7722b5c75f255_0.java → good/Gem.java
# Copying 5163fe146745ddcc561642cf228ecd6c_3.java → good/SearchNode.java
# Copying 036e9cdd6d99b250ca1908bc3d5a5c6b_2.java → good/MyCustomView.java
# Copying 4b0f4789ce0d43b6266458f315b014dd_10.java → good/ControladorUsuario.java
# Copying b82f763c6a6bd6e559b6790b6d933b86_3.java → good/LongToStringModule.java
# Copying bd184ef124acd7acc5419e60c69f87a8_4.java → good/RandomWordList.java
# Copying 85fa0eb20e4e2a76ab4d7248d3102c06_0.java → good/OrderController.java
# Copying 5926650d3030f020c83c3764ccb3db9c_2.java → good/UINavigator.java
# Copying 0e55a496cd1e20504eeb83a61b66ce19_3.java → good/CatalogServiceImpl.java
# Copying bb04dc3e7228270bbadfa8967e018d04_14.java → good/TestConsumer.java
# Copying 902b687d0676dbe576a567ff735cb63c_8.java → good/Libro.java
# Copying ab952891b87be5440bddc416dcea7c1f_0.java → good/XXSFilter.java
# Copying 49b155511a339149deac5f2d50b001e6_4.java → good/JPAExecutionAdvice.java
# Copying 465cb8940e8e18a74c01a7bc3ad5edc3_12.java → good/GoodsCatalogTempService.java
# Copying ca5cc780338c2984e831e4868df631b7_1.java → good/CustomInputFormat.java
# Copying a974d78fbd0e24fddb9c303b0275b24e_1.java → good/MyCacheableInterceptor.java
# Copying 4d56a69aab1d05ffd71afc3486250e03_1.java → good/Person.java
# Copying a81ec0142d6dce0f797e2f5d7f5a5e9d_11.java → good/MyClassTest.java
# Copying 535816807c9830909a2713b4ee336316_0.java → good/UserDto.java
# Copying c4791430f8ef2b5faf2234d79cfd69f7_16.java → good/RadarController.java
# Copying de36c3ab4acc9d780b69964a1b4f85dc_6.java → good/RequestResponseFilter.java
# Copying 08cb008cffbb2b1bcb56edfc25baec3e_4.java → good/SkCommand.java
# Copying 0245bb40404685d3e6bbf99a3391a959_28.java → good/MiAutenticacionHandler.java
# Copying dd81f778423fdc3eddacb1b02638296a_0.java → good/ParentClass.java
# Copying 1e7016028812a03754e447433aec8dfb_4.java → good/Physics.java
# Copying f8329e4aa181156a66c42cb0907793c2_12.java → good/RedisTenantAwareCache.java
# Copying c7a11b77bd3bd52eedf666a4c6d9143d_8.java → good/MybatisPlusRecordSinkProvider.java
# Copying 4550c0e03218c1a01de3d53b1de8e390_10.java → good/MiningCore.java
# Copying 8576faf3e2e50d6beab87c8b88192bfb_17.java → good/MessageSourceConfig.java
# Copying 9e04651e4c13d06b58d5fed7996feb1f_2.java → good/BasicCalculator.java
# Copying c7fa41f538892fe364d6b0fda23c4998_3.java → good/ApiController.java
# Copying 69169e60cb594ea2f5105b3ac2828a6f_10.java → good/OnlineReservationFragment.java
# Copying 215dc8c3b15dcb2b705bd522b5e01d26_13.java → good/UploadController.java
# Copying bb2719889d775ee3f0d71df39a50b340_1.java → good/MyModKeybinds.java
# Copying 3e74469fd61af865b90a6c26c89034e3_2.java → good/SqlOnlyAspect.java
# Copying 62e1cc69448e6c6b50709e442e4291b8_28.java → good/ValidadorEmail.java
# Copying f6101333be88257f7bada8e93e2a9a4a_0.java → good/Utils.java
# Copying 2fc7abbee2cea10700476570e4877067_0.java → good/FactsCollectionServiceTest.java
# Copying 9d3027b38a7696c647dc465cd7a547aa_2.java → good/EsbExampleTest.java
# Copying af901149e3ba1d255e271f0a8e258bc9_1.java → good/WidevineDRMTest.java
# Copying 1c3767860affeb923a9736d2fe92bedd_4.java → good/DisableRegenListener.java
# Copying a9fa0f8e0ce21271ada43f95fe6b3dc2_8.java → good/MyFhirServerConfig.java
# Copying 48fa3af71646b56ea42be408b64f8220_12.java → good/TextToSpeechController.java
# Copying 0ac2f6c7a5b0aa8382804d09887ecb2e_0.java → good/SimpleDeepLearningNetwork.java
# Copying bedd0d6ab19c9b28da80f58a9ca54f63_11.java → good/Menu.java
# Copying 1d8dd9010f3adf1d819b5ffe23c5768a_4.java → good/ExampleTests.java
# Copying df52eebc224a67c62e769638cb032d77_6.java → good/Windmill.java
# Copying 7b18813a5d8ec573f3134dc0a4206ca7_8.java → good/UserService.java
# Copying 90b71762ca1f8a7a77149fbb2b173ae7_1.java → good/TestClass.java
# Copying dea403080a4a2b68a3c4b284414ee98e_1.java → good/CommandSyncData.java
# Copying 9ae7aac1d4312fd8d66e9afb5c84b975_6.java → good/MainViewModel.java
# Copying 3d729f966ae704cbfe25108d1fbec9bd_1.java → good/CalculadoraService.java
# Copying ebe7e2e37488b87c9c90a00bf37cafd2_10.java → good/CameraActivity.java
# Copying 4944627f149a557cf9a55e288af77942_2.java → good/KeyDetector.java
# Copying 7efc8338a192b41ba4d41292c31a2b9c_10.java → good/NotesActivity.java
# Copying 54c3cde4c1265187c41ad20ddd1886c7_7.java → good/RetrofitClient.java
# Copying 2d0d9b65d54b5b74a269c6bc042bdccf_10.java → good/TaxiPartitioner.java
# Copying 81cbaaa9b7597759573fa13d4154b28f_19.java → good/ProductTypeController.java
# Copying 050958db49125b2030a09f124c4325df_0.java → good/BountyPlugin.java
# Copying 81ee47eddfb144c3626316b2db8fcece_6.java → good/FirstFragment.java
# Copying 7be1f6337986910eb2eae7fc48b47ff9_2.java → good/CustomGridAdapter.java
# Copying 671d1d9245e1b6f0edfaf0f835d2f4fa_10.java → good/ResponseCodes.java
# Copying 7c77734623da93eb87591d6dbc161b54_0.java → good/Student.java
# Copying 4550c0e03218c1a01de3d53b1de8e390_7.java → good/StatsCommand.java
# Copying 3614bc399d80839e303776b9a4c796ab_2.java → good/CustomLayout.java
# Copying 564a0e888f1ac416e695e96f67d205f7_12.java → good/BookController.java
# Copying ad42a484e50740b08fd2f5e412327731_2.java → good/BatteryMonitoringService.java
# Copying 01ca5536e1670275c5431ff2247e411a_10.java → good/TestExecutor.java
# Copying 46db16de1618bdd0b0fb83184eb05b04_3.java → good/RateLimitController.java
# Copying e7caf7d180f0f31892905281e0dccd21_1.java → good/DynamicSqlExample.java
# Copying 0ab3b19a26860c0837a8897ed8fe99cb_9.java → good/MultiDataSourceService.java
# Copying 4bd84b4f825a0eda395b3ce533e2d29e_0.java → good/SpeedCheckPlugin.java
# Copying 00025badb6bf2c882aa37054079c1166_6.java → good/FileUploadController.java
# Copying 83947040dad728657b8cac565be62484_2.java → good/CiudadanoController.java
# Copying 21ca2826be1255087cc73899966caea2_8.java → good/TransactionListenerImpl.java
# Copying 7750234cb4d1d35cad554d6b6db90720_3.java → good/DogDaoImplTest.java
# Copying a974d78fbd0e24fddb9c303b0275b24e_6.java → good/MyCacheEvictConfig.java
# Copying 04d27b629ae3602e2b3748023d13fb7e_0.java → good/TurretTracking.java
# Copying 10a1b82752ca064c385bbb8f17ade3bc_9.java → good/EmployeeDao.java
# Copying 57759612e6368583019dd9d507fb7a82_2.java → good/RentInfoFragment.java
# Copying 13f6338972576eb86a838c5bab790a66_6.java → good/RateLimitConfig.java
# Copying 6e49d2dbd2d6cca36c4ef983b391d617_0.java → good/PrefixPlugin.java
# Copying 6021be383503f0a7d20d9b1b9362b422_6.java → good/PlayerMovementListener.java
# Copying c03fc7e056cd5d925231d994da49bf6b_5.java → good/Parent.java
# Copying bd08adcc1cae595d17e68d092662a81c_6.java → good/SphinxPlugin.java
# Copying 3a52f7eeea2ba9f0b35fc2e48372ccd1_3.java → good/LockCardController.java
# Copying a22cc7f25e5ef423af5f3ee5c628b1be_0.java → good/Superclass.java
# Copying 429819ac9c7a8f21d52450ef3b535c96_3.java → good/YourClassName.java
# Copying d95eeda336d502a4123fb25da2b3b5e6_1.java → good/FilteringPager.java
# Copying f787e5a6a864afa653c2905cc1d7ca25_26.java → good/LorentzianDistanceServiceImpl.java
# Copying b399b9b7cbae8c1668737258adc0bb9f_0.java → good/Overload.java
# Copying 9bc092c3c49b21f33ddf2dfde887abb2_1.java → good/MyTable.java
# Copying d5ffdf695700932a7fc001e2ca23e312_2.java → good/YourEntityService.java
# Copying 693fd18076bf4bdcb9c4ba72f2206ec6_4.java → good/CustomLDAPStorageProviderFactory.java
# Copying 49016fdf521f3adb018b20a12859f4d6_4.java → good/AsteriskService.java
# Copying 85e675dfd6ddb0396c7c0a99509347ad_1.java → good/UsersApi.java
# Copying 3fede09bf74bba57136a1493b0863471_8.java → good/CouchbaseConfig.java
# Copying fd7846a52c92b544ecccdadd00ee01d2_3.java → good/InputOutput.java
# Copying ed5e785a932fc92372ec719685b5fe7d_1.java → good/MenuManager.java
# Copying 9334f09f4726c62959bc3e1d0a3448bf_1.java → good/PostController.java
# Copying ef48b10508d0cdbdd0ff9edf942eaf1a_0.java → good/CustomContainerPlugin.java
# Copying 30c0a0584ab82bb7c243e1cf0892105c_1.java → good/CardMarket.java
# Copying 7083b77de61752b619441386c8788074_2.java → good/Vehicle.java
# Copying 48c5a190c0176a4eee13c9b5fcd48847_0.java → good/Portal.java
# Copying 4b0f4789ce0d43b6266458f315b014dd_2.java → good/LoginManager.java
# Copying f3081df7b77fb9f8b51c4bc1d01ccfa7_0.java → good/MyModel.java
# Copying c21f79a2cddebbe91fe42fca6cc84b67_0.java → good/XssFilter.java
# Copying 5558cc1ee76343fb8072c2cd12d858d0_1.java → good/CustomMenuPlugin.java
# Copying da3ebc7f4781965301740093da49dae0_5.java → good/Game.java
# Copying 9c51c592e7ab7b8dbe78d852dc449266_6.java → good/CustomAgent.java
# Copying 01ca5536e1670275c5431ff2247e411a_15.java → good/RemoveOperation.java
# Copying de36c3ab4acc9d780b69964a1b4f85dc_9.java → good/AuthorizationFilter.java
# Copying dcbae9d3291b00a4ad7ae3656120c2e9_8.java → good/Node.java
# Copying 2fe5330950036794e0f37c655228c24b_4.java → good/SortWorker.java
# Copying 49016fdf521f3adb018b20a12859f4d6_2.java → good/TwilioService.java
# Copying 112ddfc35d3383bfddc5937eb5d6a8df_2.java → good/RoleNotFoundException.java
# Copying d675d3f375281420e481e6730efc49da_7.java → good/MyActivity.java
# Copying 5e047ab8d1de8f14bd960abb188b93fd_0.java → good/Player.java
# Copying 4830d745c8bac97686dc122b9d537be4_0.java → good/Sorozat.java
# Copying fe84fa4c3d27dbb6bdedbca22b2fec12_19.java → good/Deck.java
# Copying 2c16724a3edd494d452cfb3ad8190336_1.java → good/SecondForm.java
# Copying 2aa2fc071fee380cde7dff863d5a69c8_5.java → good/RedisService.java
# Copying 3e5df7ce663e57201dd6816dd651a6d7_2.java → good/StringUtils.java
# Copying 0322511a1c87358ff50058a4875d6847_3.java → good/Pair.java
# Copying 4e86af350f87a2070b2b451ea16a1084_2.java → good/LoginFragment.java
# Copying 872a7b958766b0b37592e90934a1e152_0.java → good/CustomOptionsScreen.java
# Copying 62dcd0b50b8c861f3bf9e5fe9c73c792_0.java → good/RequestObject.java
# Copying 5066aee18d77813b3bd6704091599785_0.java → good/Car.java
# Copying 970cf3e23a8bc9135b43d1f043f2c8ff_0.java → good/PhoneNumber.java
# Copying c876c8b24771d10fa80fcdbfca5aec76_0.java → good/Action.java
# Copying 85e675dfd6ddb0396c7c0a99509347ad_5.java → good/OrdersApi.java
# Copying 617b50d73eb67c512a6b8ff510ade68e_3.java → good/CategoryUtil.java
# Copying 5af7dfa548f420c9a2341d59666e5084_2.java → good/SocketClient.java
# Copying c3cb0c494d8889973bfa3bb417482e08_3.java → good/MyEventHandler.java
# Copying 3563fc474afce6b609408c070b7eb800_2.java → good/EnterprisePurchaseListener.java
# Copying 288ad3f239acc7d3dfa1b5e563583af9_1.java → good/TShirt.java
# Copying 84cd2b5633413b645a78c21b59f0ea9c_11.java → good/AutocompleteInfo.java
# Copying 614b877245d6a71adedaff0a5744af3d_21.java → good/KHashNode.java
# Copying fe5291de9c586f5b113f8d55c3680cbd_9.java → good/AppConfig.java
# Copying 6fc94701ac414afeb8c381cad8c63118_0.java → good/MongoDBItemWriter.java
# Copying 0322511a1c87358ff50058a4875d6847_4.java → good/RecyclerViewAdapter.java
# Copying 540d6216258a93904ce5dad60d57a1d8_1.java → good/Matrix1.java
# Copying fba215cb212bff7d55765e8c6c689ea6_1.java → good/Receiver.java
# Copying 5a19b6d27dc687a0cd752f60e0529df9_0.java → good/SwordSpeedMod.java
# Copying e348f22a90227f5053b10bf7a1dbb9e1_0.java → good/HealthManagementSystem.java
# Copying 0aabb229a6394aeab8e22dc1ac67d92a_5.java → good/MyInitializer.java
# Copying 6150322426413e690de1a4f14b59a48b_0.java → good/ChildClass.java
# Copying 0aabb229a6394aeab8e22dc1ac67d92a_4.java → good/MyCommandLineRunner.java
# Copying 85e675dfd6ddb0396c7c0a99509347ad_8.java → good/ProductsApi.java
# Copying 90bbde27d1edb06228de0ce2e0c26163_2.java → good/MyService.java
# Copying a82e633342ab58a09a71c307456c6b9f_2.java → good/SecondActivity.java
# Copying 3c98aa4edcb6591b9b3f56469870fd09_19.java → good/ConexionDb.java
# Copying c446f65e349b6af7bdb3c3557df50dbd_4.java → good/RequestProcessor.java
# Copying 3c9315f465e1640c7c47b1162c4fb49d_0.java → good/DisplayPlugin.java
# Copying ac62baf0da2de4c05da374fc648651b3_4.java → good/Names.java
# Copying 8b3b04b3fa85f44050534e7fb2efdcc1_0.java → good/SharedBuffer.java
# Copying c71cd5792bcfa463899f9511354e3311_3.java → good/PlayerJoinEvent.java
# Copying 432984ad455b8ca80ef1ec25abd548b7_13.java → good/MyBean.java
# Copying 374755891b4cac2f779c79f88f171eca_0.java → good/Sondage.java
# Copying ac0e1110da39ad78f8225c552249eef0_11.java → good/Register.java
# Copying 5e03a41e5d3b965b72507486e32a4209_11.java → good/RegistroService.java
# Copying c8d93dffa0c5c99603feeb9f25bfa9d8_1.java → good/MyMod.java
# Copying 906a5827ccbb1ad173941b072700a8d6_0.java → good/CipherDetails.java
# Copying f8ef0e1c3c79744ae4da8b9cd8315a93_9.java → good/PluginService.java
# Copying fe73289ea2b9c405e2d8e81e4e900b30_0.java → good/ReviewManager.java
# Copying 04092568a33cb9a281c47c4d59e87143_0.java → good/ModMain.java
# Copying 2c23b2f4946b61abfba77dd4dffae309_4.java → good/GetTodoItemsQuery.java
# Copying 24835248e0c72c0ea4ee386a7a1fffd3_1.java → good/CustomTaskScheduler.java
# Copying 3bc88a0067cb5731ce110694e9f120c6_9.java → good/OkHttpClientConfig.java
# Copying 159050e86c912d0fdb58031b5bfb28c8_5.java → good/SearchRecordService.java
# Copying 374755891b4cac2f779c79f88f171eca_1.java → good/Serveur.java
# Copying c446f65e349b6af7bdb3c3557df50dbd_6.java → good/RequestController.java
# Copying 5324e195d6614aaa6af27c9e33de8c29_2.java → good/NetworkConnectionThread.java
# Copying ecf96e124a2ddc2ec293436dffeb995a_0.java → good/Course.java
# Copying eeaa5e328c2011ae20f7892fb1c96c7a_20.java → good/LoginServlet.java
# Copying e54e06e281dc7a9ef71094e2e794d8e5_0.java → good/CarRental.java
# Copying 756d92857bb4cc60a4c827f132bc5803_0.java → good/WaitingLineSecondary.java
# Copying 21afcc0801aab0d0f476749c2faeccc3_3.java → good/CommissionEmployee.java
# Copying c26425417e6106a64e2fa9121c13d0e8_0.java → good/MenuPlugin.java
# Copying 298d3ea8cac14803db6670adb7f14d3e_7.java → good/Server.java
# Copying f8744ccff1c51162fa6376e8cbc8aa7c_1.java → good/MyApplication.java
# Copying 0b27669ed4aa5db14236d8c006f35bac_28.java → good/BetterDolphins.java
# Copying a6b961a8d9268b352adad3df7f48cb0d_13.java → good/LogAspect.java
# Copying e513490bd5b27ccb117ba7bb3207a957_0.java → good/Employee.java
# Copying 5ff9b6feab2b8ea9199a5ac6ea8a2245_1.java → good/DataSourceConfig.java
# Copying 56b04eb465d91711c34f38da55ef56af_4.java → good/AppInitializer.java
# Copying 9852d6a491b7585e47b73c8d5b3c6b15_23.java → good/TicTacToe.java
# Copying 576dd8afd09f4d4e979bb3cefe548445_9.java → good/VueAdministration.java
# Copying 8d8aa7d16f24dd9eaaa23a527910e09c_0.java → good/QuestionAnswerController.java
# Copying e68d80ecad20d157b426d79c0522c0fe_1.java → good/AttachmentService.java
# Copying 515c66d4d471bb91e59baf31a3044fa0_2.java → good/VideoEndpoint.java
# Copying 6190790fd73cdb7ea29c9a5bdfc8854c_17.java → good/Fract.java
# Copying d4c73b9252334f1097123b78f9eee73c_6.java → good/JsonDataStore.java
# Copying c06b9c80220145178ae5bdef9f4c1a3c_4.java → good/PersonController.java
# Copying 77af572ca2956177f29548a1051a8b5f_0.java → good/MyRunnable.java
# Copying 21d736bf29bd2462c1ddd3e8d89f975b_1.java → good/OrderWriter.java
# Copying f808ac61b8a57c2ff25093fb233caf68_4.java → good/StoneReplacementPlugin.java
# Copying 186e8d07bd2f81c34f8dac9653208644_1.java → good/CameraPreview.java
# Copying 6e76d83fd37bc724a2ceacbfaf79d323_14.java → good/UserRequest.java
# Copying b78dfc7af92fc0df343c1be8c6233eb0_1.java → good/MainImplementation.java
# Copying 99280f0e57d354c120b063b6ce0a8bef_1.java → good/GeoLocation.java
# Copying f21ed63811d99ea48c1507574fc3820f_7.java → good/HospitalUI.java
# Copying df17ff2689330a7c21227668939c3577_34.java → good/CglibProxyGenerator.java
# Copying 7e1ae62a7e12b1da2a0bbc77d4d63d86_1.java → good/FoodSpawner.java
# Copying d55085ce985b036866bda9b60eb04ec6_3.java → good/Stack.java
# Copying 7750234cb4d1d35cad554d6b6db90720_1.java → good/UserDaoImplTest.java
# Copying 8d2764a95003157faba7d37852f99533_0.java → good/Cliente.java
# Copying 14036fc2f9d8d6cff820325443547590_1.java → good/Edge.java
# Copying dcb5c7904d713c9a3cb81b4dd0af651e_11.java → good/JwtAuthorizationFilter.java
# Copying 7fb5af87c9fff4e893cb8ae0556ee3fb_8.java → good/KNNParam.java
# Copying 2df83cb687dc41e34b706ee17ad48ddc_6.java → good/WordToPdfConverter.java
# Copying 159050e86c912d0fdb58031b5bfb28c8_4.java → good/SearchRecord.java
# Copying e0b0f9332ee38a68e753b3efe69eb15d_1.java → good/DataSourceTransactionManagerMockTest.java
# Copying 53b766371f025df10cbb38be1e2c6a3b_1.java → good/WeatherEnthusiast.java
# Copying a9a053f6ecaccac7f6c88b3014033eb9_3.java → good/CustomInvocationHandler.java
# Copying d29d773758e5d36b03e5dbcf99de62b1_15.java → good/ImageToH264Streamer.java
# Copying a4497fdc6a8575076e1bf3d4b7a95ebc_3.java → good/EditContactActivity.java
# Copying 2a69dc92d45ed1176801bfec34474987_44.java → good/SideMenuController.java
# Copying 9e7871ef23abed3f5f42012ef2d46314_9.java → good/CurrentScore.java
# Copying 26bd282ddcac877f6aef97e26883db38_6.java → good/BankA.java
# Copying 6b78bde94c3afc48ff37e12b82b5493e_4.java → good/HibernateSqlAspect.java
# Copying c1b3bd0a81593d41c85d24c2949f8670_4.java → good/AuthServlet.java
# Copying 714a03ad30fc67429c07466130e23b00_11.java → good/InfluxDBConfig.java
# Copying b4b914eac23c78a6088e7d5c7a0c0f2c_1.java → good/RegistrationFragment.java
# Copying de36c3ab4acc9d780b69964a1b4f85dc_3.java → good/EncodingFilter.java
# Copying 0dae3152011cb60981bf24b726e02bbe_7.java → good/Item.java
# Copying 129412f54785227d390ae378747e6fe1_11.java → good/CategoriaVO.java
# Copying c605b3fe90c5f2242d979db4dfaffac0_9.java → good/CustomDateSerializerDeserializer.java
# Copying 924b23d2fdc08865070f54776c6f3113_3.java → good/AlumnoResource.java
# Copying a6b961a8d9268b352adad3df7f48cb0d_16.java → good/HelloGrpcService.java
# Copying 86786e1dd2e1730ae852d0c857fc6f23_12.java → good/HelloController.java
# Copying f82cb1f0394bfab2864cb4ef02d6f9e7_0.java → good/JsonFileHandler.java
# Copying ec49ac1efc3e967354fdab96bbc2f746_1.java → good/MainPlugin.java
# Copying 1c3767860affeb923a9736d2fe92bedd_3.java → good/YourPlugin.java
# Copying 3eba49021a441f5ae45e8b253fe84b5c_3.java → good/Image.java
# Copying 5c87e21aa800d308b6b0b47a092227d0_5.java → good/MyDebeziumDeserializationSchema.java
# Copying 5b2134ade0e6c445acc08f66bf40ad9b_1.java → good/Alumno.java
# Copying c33612c566f14310ba4092e1104549a4_2.java → good/Sack.java
# Copying edbdb5bd1e170b1fc6f7bdff7fd2273b_0.java → good/CollisionSpawner.java
# Copying 2b8cb71fcf7f272ffdea6a488e387ade_8.java → good/ServiceViewModel.java
# Copying c5e343f6bbbfabc0a219b51acb91fbb4_16.java → good/Producer.java
# Copying a72bc1a6a2b923aa1df839ca0e959239_3.java → good/Strings.java
# Copying ad89b6a3e3f454b09a4fb17b6c05bfc8_2.java → good/ObjectADaoImpl.java
# Copying 597cde707179ea61005cefb7fd96a697_9.java → good/SwaggerController.java
# Copying dcbae9d3291b00a4ad7ae3656120c2e9_3.java → good/Renderer.java
# Copying 29aeb186918e752e1da25a172a8a7fc3_12.java → good/Encryptor.java
# Copying 28f9e1df0a2a18b8fbf0d3d4154918a0_3.java → good/MyTestClass.java
# Copying 770ef5cfe0cc267535ec169816539675_2.java → good/ClientEventHandler.java
# Copying 7439031740256026a51c9c9a50a65137_4.java → good/FeignConfig.java
# Copying 9c6d7f82158ab5b5fae4e0d501e422b8_4.java → good/VirusTotalScanResult.java
# Copying 1d0b7760bbbd2d5217a9b2c6a49b7295_4.java → good/BinaryTree.java
# Copying f3ae7bf8b127b184132196f88d612096_2.java → good/VibrationHelper.java
# Copying 649d65d5cfffd1c40cf029496a6a8407_2.java → good/Dog.java
# Copying ecf96e124a2ddc2ec293436dffeb995a_4.java → good/Validator.java
# Copying 5778894d7fb255a792f1b97b8cd74f7f_0.java → good/MyWorker.java
# Copying 10013f0ffbdf5db99334620eee07e47f_11.java → good/MyFeignConfiguration.java
# Copying a984f6d13d811ad803e4f7e87a1b46c7_5.java → good/Laptop.java
# Copying bceb95c0305cf3fa361b2b550323f0aa_11.java → good/Case.java
# Copying ed414fdd84eec7331221873616a4c88b_1.java → good/Application.java
# Copying 2deb5f881f760b93aae2ecc1ce88c589_3.java → good/FileTransferServiceImpl.java
# Copying 9d836304fbc5bf3c8dbc593e99ae5652_9.java → good/CacheRefreshEventListener.java
# Copying 854eb9cb741e42552562a5fbd0151d36_0.java → good/Proxy.java
# Copying dfa6a6b551db63b15f7ae84eff714e54_4.java → good/AdidasCommandExecutor.java
# Copying fcba91e4b4ad35d924006b122f695f8a_4.java → good/RateLimitingInterceptor.java
# Copying b5fb84532b45e9fa27639336005fad8e_1.java → good/Wizard.java
# Copying 8f2b162d6b63e49b3a1b34a15dc1cc42_6.java → good/CustomEventArgs.java
# Copying df16b67bd2890fe2fc92dc6967d54410_1.java → good/DictionaryLoader.java
# Copying b1428863b803608f3170b53b95d287e9_6.java → good/CameraMod.java
# Copying 29734925d7545aa095ac8137701e4496_10.java → good/SentryConfig.java
# Copying e8f28dee0f3f664d0262bb7a5783f65e_0.java → good/Osoba.java
# Copying 924b23d2fdc08865070f54776c6f3113_15.java → good/ServicioAlumno.java
# Copying 36812f61fff1bf512e07775bddcfadda_0.java → good/MulticastListener.java
# Copying 96a55fb3bdee3d4980250c412d183f9f_2.java → good/MapsActivity.java
# Copying ddcd9ed67f3c80aa46600a3350c52b9b_0.java → good/AbsErrorException.java
# Copying 1a11e00aaac628e139ab9c87993b6ec6_2.java → good/EcertServiceService.java
# Copying 83947040dad728657b8cac565be62484_1.java → good/Ciudadano.java
# Copying 0bbe1c282c8ef7f86cb9c87a3c245314_3.java → good/BookManagementSystemImpl.java
# Copying 8aa4e455406d2467b9b73cb4dc01a588_0.java → good/GameManager.java
# Copying 050299bb235952046ca35c8ae501af46_6.java → good/SomeGoal.java
# Copying 055831db8109e560a5e9f0b7eef6b610_4.java → good/MyScheduledTasks.java
# Copying 3f8e541ce153f204f9188f850887f0e8_1.java → good/CelularWS.java
# Copying 80c4756a11c8bc711315b35ef0308138_7.java → good/EstudiantesList.java
# Copying 8576faf3e2e50d6beab87c8b88192bfb_22.java → good/YourService.java
# Copying 398a2b80fd2248a6d27b0ae0f0c13dc1_2.java → good/VibrationUtil.java
# Copying 3628ded635a9e776b6bbf811b321d94d_4.java → good/Кафе.java
# Copying 3eba49021a441f5ae45e8b253fe84b5c_1.java → good/JwtAuthenticationFilter.java
# Copying 770d94a4672b42e4ec737da2e961f13d_1.java → good/WebSecurityConfig.java
# Copying 896a94923c30c73a446492dcde84945d_5.java → good/TimeConversion.java
# Copying 6598f5dfc0456406b75e7ed33cafad19_13.java → good/FirebaseDatabaseUtil.java
# Copying 8dd5b02cfa8b70f4657336bf96053fbe_20.java → good/StockService.java
# Copying 12c65393de3c3018f9aa9b4bd1e026bd_0.java → good/MyPlugin.java
# Copying f81c291e5708d17a4ec5f2a33ed00274_3.java → good/Packet.java
# Copying 8dd5b02cfa8b70f4657336bf96053fbe_19.java → good/CacheConfig.java
# Copying aba7268e742b61c699f1ca17e9a17745_5.java → good/TradeAnalysis.java
# Copying db1cc6978d349dbe94fa2bb3b08ee5b5_3.java → good/FraudMonitoringService.java
# Copying 2e7b17e6473fc032431670f3fb064122_0.java → good/MyTask.java
# Copying d594f80154f025c856c2606fb2a50d9d_8.java → good/AccountCommandHandler.java
# Copying 397cc5b6f7c2da7f3da411b7f4e5c062_0.java → good/MongoJobRepositoryFactoryBean.java
# Copying d1d17725f38a4ed39fbda7e5692ee7fe_2.java → good/BlockBreakListener.java
# Copying cbabcba2f499c10cea4cf86a30884a9b_3.java → good/LoginLogProviderImpl.java
# Copying fb51873ad537df8b0d5673b1a47b0af4_0.java → good/HelloWorldUDF.java
# Copying 48c5a190c0176a4eee13c9b5fcd48847_2.java → good/ScaleToPositionScript.java
# Copying e0384d8e04457171e710a6a5715e8420_0.java → good/MyModItem.java
# Copying 94008b863c48fe947b360c25cc7ff2bf_2.java → good/FastCobblestoneRespawn.java
# Copying d5791aab85626f316df192c91ce8f1fa_0.java → good/ServerConnectionManager.java
# Copying b63b19478bc4b097dd49fded8cef5f9a_12.java → good/ResourceNotFoundException.java
# Copying df7c42051f9146b0148baa13845f9dee_0.java → good/MyScreen.java
# Copying 159050e86c912d0fdb58031b5bfb28c8_2.java → good/LogicDeleteInterceptor.java
# Copying 31b596d572057c69973c9329316c05e2_0.java → good/MyUser.java
# Copying d69f7137503fa0189c050ab037d76c07_1.java → good/BaconItem.java
# Copying ac94534e00b37b7bae183bb405a50ec6_3.java → good/RedisConfig.java
# Copying 686688c40da7c488e2061351e45e9ad4_1.java → good/HibernateSessionFactory.java
# Copying fba215cb212bff7d55765e8c6c689ea6_2.java → good/FrameReceiver.java
# Copying 5a481d60644e32686e7177b4cc6f0205_0.java → good/CustomErrorController.java
# Copying bafab705236783528969d065363f5d58_2.java → good/MathUtils.java
# Copying 564a0e888f1ac416e695e96f67d205f7_13.java → good/BookServiceImpl.java
# Copying 995eed5bc6125337f2be004465c0496c_2.java → good/StocksFragment.java
# Copying bf7790f58e956aecdd1a22091f8d2877_0.java → good/MyNativeModule.java
# Copying 6ead9e47c888aebba7f267a541273c93_8.java → good/PersonnelServiceImpl.java
# Copying b4c473262824d17ff29e9d4be20f1548_0.java → good/Notification.java
# Copying 927d064c6fe0ad6ef1137e92581640a2_5.java → good/Question.java
# Copying 564485241e49a937d659de574ccb14c8_4.java → good/ConcorsoRomanzoFactory.java
# Copying f1e657c472b3b8c903ad7fef599d6b64_0.java → good/CaptchaPlugin.java
# Copying acf577435e571a9c8f20fd341c08ebfd_1.java → good/Example1Impl.java
# Copying d5e75c0bb4367d08ac65dfb61c02c521_3.java → good/CareerController.java
# Copying 379577d3a74ece5557c331bfbbafa9f4_1.java → good/EmailAuthenticationStrategy.java
# Copying 1ba8406de5c652b9dfca6b2fdc2020b0_2.java → good/TileRenderer.java
# Copying 586f8054570e6da9eb0e26c100ac36dd_1.java → good/ImgRequest.java
# Copying 6311fad4481e6ece674b4ea2f0ed5b0b_0.java → good/CustomRestTemplateCustomizer.java
# Copying 2a69dc92d45ed1176801bfec34474987_25.java → good/MainViewController.java
# Copying f51a2e443603c62ad466e87f67daec9c_13.java → good/WebMvcConfig.java
# Copying 48232d5675b7c1a9b20a7f2c02e3ce9b_0.java → good/KlasaGlowna.java
# Copying 538c5e3a8dbe44a1b11a2542c4eeabfe_2.java → good/MyThreadLocal.java
# Copying 3c49ccbf995a40a437b9f615adfbaffd_6.java → good/CRCUtil.java
# Copying 8831413db8454521ee3eca383dc596b3_2.java → good/Analizador.java
# Copying 339bf8eb19105afbb2232fdbee4179aa_2.java → good/MarginBankRecordServiceImpl.java
# Copying f1956b0fae9d0875ac26146a513c9f7b_0.java → good/Calculatrice.java
# Copying ab952891b87be5440bddc416dcea7c1f_2.java → good/WebConfig.java
# Copying 75c18637b09dcac30d674a38fff34ef7_1.java → good/FirebaseRepository.java
# Copying 020d4eeb2aa22328a1cf5947564b7798_14.java → good/ClientMain.java
# Copying 8030b79e8a751fcbe53c7be3b20fad67_5.java → good/MyWebSocketEndpoint.java
# Copying d4c05236dcf3a601c5637984bdd32a19_1.java → good/Lavadora.java
# Copying da4baa1bc95d0279a8c0c3003b8902a3_3.java → good/MyModule.java
# Copying 42965129d4d8ab3359763eb230774736_0.java → good/Produit.java
# Copying 1029df6c4cc44db28117aefe4e90742c_0.java → good/BankSetups.java
# Copying 2d60bc8efed76aed4ca092df17a2b57f_1.java → good/Point.java
# Copying d594f80154f025c856c2606fb2a50d9d_4.java → good/GetAccountQuery.java
# Copying ad9c7a952a0cb65f67ccb85e1e0e85c5_6.java → good/DetailActivity.java
# Copying 3afd3f4dcae3d2b0571494085e455975_6.java → good/name1.java
# Copying f4717d7b7e0bd5499c8f8f9223c99700_19.java → good/PeliculasDao.java
# Copying 637a6987cb7bf3f8fc1f8f14cf593c50_2.java → good/HttpUtils.java
# Copying 1ab454a8df2089045dc30043390553dc_0.java → good/CustomPrintStream.java
# Copying bc9d82b0f1ff997781ee82748fceec5c_6.java → good/BasePlusCommissionEmployee.java
# Copying 592dde17e44503b677286d6f6822ea59_0.java → good/RubPlugin.java
# Copying 1c1a79c7603d3969e1b898e03245e418_30.java → good/PostProcessor.java
# Copying 77dbe09823d3659c42ee6d3dae05f47c_0.java → good/DownloadServlet.java
# Copying 6e6009ee6ea2cdbec177ba59c11b6fc5_1.java → good/PedidoWSAuth.java
# Copying 24835248e0c72c0ea4ee386a7a1fffd3_3.java → good/CronTaskEntity.java
# Copying a7321ab88fd92dc43a0ea45e7b6f2c14_1.java → good/YourRootElementClass.java
# Copying d528beb6ac1d0b8affd6329cbbe88212_0.java → good/JmsConfig.java
# Copying 52d6c74643befa7119b17ec4d0fe13d3_19.java → good/Test.java
# Copying a897e009e1660f1e749e8b80babc8507_4.java → good/MyWebTest.java
# Copying ad33279cead60d84e40086c565bf2c8f_17.java → good/ActualizarUsuarioActivity.java
# Copying e5dd8f340149cf2f2d87459e91cc682d_27.java → good/PedidoWS.java
# Copying 85fc1115f79be479121b6f5c6113df4d_1.java → good/StatsManager.java
# Copying e7201650d21776ae44ca0aef3cb2c244_1.java → good/DataSource.java
# Copying 0aabb229a6394aeab8e22dc1ac67d92a_13.java → good/JFXMLBeanDefinitionRegistryPostProcessor.java
# Copying 9e7871ef23abed3f5f42012ef2d46314_0.java → good/Principal.java
# Copying 30ce0ca6e3dc0685d3858e7fbc23b37b_2.java → good/Assignment.java
# Copying 8d4181baabfbfd9c7a7cd569796789a0_2.java → good/LicenseService.java
# Copying cc8f0b8f9495d1bd6670b5c0af874985_3.java → good/University.java
# Copying 3d865a7bf4ea923425ffb4cd49c74873_9.java → good/Aliante.java
# Copying 69169e60cb594ea2f5105b3ac2828a6f_3.java → good/SharedViewModel.java
# Copying 00c741d298d9dbe1e2229dc9d4ecdda9_1.java → good/Customer.java
# Copying 857d5ca29d48ffcf2b5d63f3640ee26e_6.java → good/UserViewModel.java
# Copying d379be797a5f3f8e6c9e7789aa6933b0_15.java → good/ChartTemplateConfig.java
# Copying 9bb7d4d816527ad6072dfc778e9bef75_4.java → good/HTTPServer.java
# Copying 1e7016028812a03754e447433aec8dfb_1.java → good/MotionComponent.java
# Copying d637365f7962c91fba6820cfa6ac6481_3.java → good/SchedulerConfig.java
# Copying 25eb6346fc391428d00755b9556113e9_2.java → good/QuickSort.java
# Copying 380e2ff0e7ddc295c2a2e96044082356_0.java → good/Character.java
# Copying 15ce695ec562aa311ea092571539caa5_0.java → good/CounterModel.java
# Copying b449928c687ee7622f8e27568f717efa_2.java → good/GAN.java
# Copying 9bb7d4d816527ad6072dfc778e9bef75_2.java → good/SSLScanner.java
# Copying 2474455231a921b62bc34ff2de0b95bb_0.java → good/MyThread.java
# Copying a16e8c1c051f4b6704a64c295bbf6dd2_30.java → good/MyBeanUtils.java
# Copying cd48beff86d6835fae0acdf22ca05167_2.java → good/FileUtils.java
# Copying 37f94aaecd05668a47f4ce13e3702461_2.java → good/TagBasedRecommender.java
# Copying 3761e977937d20fcbcbc196804ce5833_3.java → good/FilePicker.java
# Copying 4c8071ac62cbfe9a2540dd139bfe8e24_0.java → good/ModBlocks.java
# Copying 6add08fdb77d5be41253a252715ddcc2_7.java → good/HomeController.java
# Copying 365bfdf3d0f4d6173b25941f909002d3_0.java → good/Waiter.java
# Copying 0d0a1b49815643707cb14a1fba3e286e_4.java → good/ClickCounter.java
# Copying c4b05bc478813763309dfac0c99682f6_2.java → good/BoardCreator.java
# Copying ce4af154ca287ef6d4e1a2774b2f72c4_3.java → good/WorkerTask.java
# Copying b6b7127233deec3fee36f40fab24964e_1.java → good/Book.java
# Copying 3bc88a0067cb5731ce110694e9f120c6_4.java → good/DatavizGraph.java
# Copying 3c9a7338549b3bab2243647be588cdf0_7.java → good/ConcreteVisitor.java
# Copying ab31d558823a0e81c6642e8343c45f7c_2.java → good/ExperimentBase.java
# Copying 4510cc13d09d846c6561f8adf93ea0f2_0.java → good/HRManagement.java
# Copying fcba91e4b4ad35d924006b122f695f8a_3.java → good/RateLimiterService.java
# Copying dcbae9d3291b00a4ad7ae3656120c2e9_9.java → good/AnnotationTreePathScanner.java
# Copying 1ea83093e45c31c1df1ba7197590923f_6.java → good/MyBatisConfig.java
# Copying 6c71ce743403e0373681d764572a2822_1.java → good/CustomListener.java
# Copying bca52a0097d765059fe9d24b7b377416_0.java → good/StickerProvider.java
# Copying 3427104b651dd8b452a19ab97207da3c_6.java → good/MyDataSourceConfig.java
# Copying 1150d1a1f8ee0e53293086af8ad50026_1.java → good/CustomerDao.java
# Copying 5d40c9a1222130e8dcbca8702433b5cf_0.java → good/NonThreadSafeSingleton.java
# Copying 8d4d402123f1391b6259b60dc07b1177_0.java → good/BazaarPlugin.java
# Copying 4370eceb56912beb04bd66365f466716_0.java → good/HOTELIERServer.java
# Copying 7f5b0fd9363ac3ad239937abe6a2bc98_0.java → good/AABBPool.java
# Copying 15dd9e2dcab5de9eb90accf36ba2a281_4.java → good/ImageModel.java
# Copying 9ed52d4167dac276bc0b0af265a88467_1.java → good/TemperatureConversionServlet.java
# Copying d67b090c9c80ca543aca7985d2355e4d_3.java → good/YourPacket.java
# Copying 372ca186982b64d143ede669d18f196a_2.java → good/RateLimitedController.java
# Copying 1a66e03d3ea31a4a971cbddf68a8de86_1.java → good/ItemInfoHelper.java
# Copying a78fe72d8a556d3a9db0825bbd88c828_1.java → good/RenderCubeItem.java
# Copying ab952891b87be5440bddc416dcea7c1f_1.java → good/XSSRequestWrapper.java
# Copying b9e67ba8ffb773ece5b20f7caa02d6a2_0.java → good/Marvin.java
# Copying 2d8352d469c1f394adb95f2c9dd771e0_3.java → good/InputService.java
# Copying 40c69465a784b57ff24d6f9127c51eee_4.java → good/RateLimitService.java
# Copying 82038ce9a92a053a49c9ae1a51b3b4be_0.java → good/TreeProcessingDelegate.java
# Copying a72bc1a6a2b923aa1df839ca0e959239_1.java → good/Instrument.java
# Copying 0af2911a00f8001e9d71bdfff3b90857_0.java → good/MenuUtils.java
# Copying 4d2f200eca286b468d5a921cad33e035_0.java → good/ChessPiece.java
# Copying f787e5a6a864afa653c2905cc1d7ca25_36.java → good/SomeDistanceServiceImpl.java
# Copying 54f00dc8cee68279bf4a3d31bbac0ec4_0.java → good/Auto.java
# Copying 847befe5719b2947bb90cfbbd1b87219_1.java → good/SecondClass.java
# Copying fd5f3a5680068b8fe30fa538b87a9502_0.java → good/EntityA.java
# Copying 27743b67ce2e0cb6f32220c0897d4053_0.java → good/TuControlador.java
# Copying 24a58dd74fdcabaeb4d1322b12602190_12.java → good/MockUriInfo.java
# Copying d75a8ade9a5b290f3b05297823571f78_1.java → good/WordStore.java
# Copying 2a69dc92d45ed1176801bfec34474987_14.java → good/MainView.java
# Copying 7772a32e9fb4889fb000b748129a0cba_0.java → good/MongoJobRepository.java
# Copying 5215d7d993f0555a07735fe4c6ff2366_1.java → good/SM4AlgorithmImpl.java
# Copying ab3ae30dbe2cf2191cb1ee5a28bbd17a_3.java → good/ActionsActivity.java
# Copying 01ca5536e1670275c5431ff2247e411a_9.java → good/Workload.java
# Copying 44030215fd3ba8501297970962fa33f5_0.java → good/MiniDB.java
# Copying 924b23d2fdc08865070f54776c6f3113_13.java → good/MiServicioRest.java
# Copying 16b9c67f2e89391345b7888a3f4bb8ce_0.java → good/LocalDateTimeType.java
# Copying 4ae56705ae0a9e54ab828f808c782dc2_12.java → good/ParallelKLineFetcher.java
# Copying 55ae5e1888218436c4326fb09501b834_17.java → good/OpenApiConfig.java
# Copying ee9e300a7cb3536c982ba790ad51cdf8_0.java → good/Analista.java
# Copying 30587fb0d64b0beb86d664be89a1535d_7.java → good/MCSLock.java
# Copying 3bc2edc60a2d2e1357da49e514173828_0.java → good/CurrencyPlugin.java
# Copying 614b877245d6a71adedaff0a5744af3d_28.java → good/KHashNodeServiceTest.java
# Copying 6b78bde94c3afc48ff37e12b82b5493e_10.java → good/HibernateSqlInterceptorConsoleAppender.java
# Copying a9be79b8a1a544c28dcb1c4e0061cf1c_4.java → good/ExamplePluginGUI.java
# Copying ac62baf0da2de4c05da374fc648651b3_2.java → good/SocialNetwork.java
# Copying f516e10133b65d08eff11b9a91b6a2e3_6.java → good/VowelComparator.java
# ...
# Copying cfdc9520bbdd46b1f917e24ceb609cb5_2.java → good/MyTask2.java
# Copying 32ebba74e8d27b7a005185561c7b3c7c_1.java → good/Transaction.java
# Copying ce348a96387462ab3b2e6501e03a3436_0.java → good/GoogleSignInUtil.java
# Copying 9e7871ef23abed3f5f42012ef2d46314_8.java → good/DebetScore.java
# Copying b667494ffe08c9d5c948260cecd91e6f_4.java → good/XSSUtil.java
# Copying 4c7abe893143fd226486c8fc82065fcc_7.java → good/CachedMerchantFactory.java
# Copying 24835248e0c72c0ea4ee386a7a1fffd3_2.java → good/MyScheduledTask.java
# Copying dea403080a4a2b68a3c4b284414ee98e_3.java → good/CommandSyncDataFromDB.java
# Copying 98778ec47f98fdf81e78634fe7b58a39_2.java → good/AlproSubCommand.java
# Copying 704acbc3617bd30448ecf8887097a63d_7.java → good/H2EntityManagerProvider.java
# Copying 33d383f1a73c26031a4e30a3ce638f2d_3.java → good/S3Controller.java
# Copying 94695ef3d4555fb4d2222359076a1cb6_0.java → good/WireMockExampleTest.java
# Copying 0b73596a8c2caf440cc0be1613798bd9_1.java → good/MyCustomAdapter.java
# Copying 6c566aa0c7b6b34a1c4c1ad41f764d66_2.java → good/EmployeesTasks.java
# Copying 02ecfb174d01570e8e4b9749c4ae7f3d_1.java → good/AnnotationProcessor.java
# Copying 0aabb229a6394aeab8e22dc1ac67d92a_3.java → good/MyApplicationListener.java
# Copying 0f9bb4314653ed701dd4caf70377f5cb_2.java → good/DetallesEditar.java
# Copying dd7da0a5a704b5d0de224cb3511703e5_1.java → good/ExamPaperController.java
# Copying 22c1599c7dd20c43b9ea03127fc94812_1.java → good/HealthSystemComponent.java
# Copying 6ead9e47c888aebba7f267a541273c93_2.java → good/Personnel.java
# Copying ae8990d2db68b6b20a9e8c77e1929601_12.java → good/CNDailyKHashIndex.java
# Copying 8ee491f05d97ce24f44e613b238c70ca_4.java → good/ContactsDatabaseHelper.java
# Copying 83011649cef6be679a338e75f510aee1_4.java → good/CreateOrderCmd.java
# Copying 1c7fc3a84fb89cb42451487017abc363_7.java → good/FileUploadUtil.java
# Copying b2d8e233145e2c7405700bdf2880ed26_1.java → good/CommonPage.java
# Copying 57814f9ee756162cced1424eb2f67181_2.java → good/DateTimeUtil.java
# Copying b92142ca7feb30ac9ab4113ddd026cdd_1.java → good/ReflectionUtil.java
# Copying fdb0276bd395a1d66ac63a503af64ffe_0.java → good/VentaComputadoras.java
# Copying bc0b105992e51de23652981a965c3f78_4.java → good/SequentialNamer.java
# Copying 19650983df154c804983b286f5160322_6.java → good/OrderStatusActivity.java
# Copying 086d54c21cab4f2d3ab9858cfac2dc33_0.java → good/KSortedArraySorting.java
# Copying 2dfc392058ae016797af973f7cc5cd82_5.java → good/ZIPClientLoader.java
# Copying 7a056a95a3556367d6f3fcb93ea5cec4_1.java → good/Office.java
# Copying a84d3592d6e5c056e29d01a03aa8111f_1.java → good/MovingAverageStrategy.java
# Copying 85fa0eb20e4e2a76ab4d7248d3102c06_9.java → good/RealFileDownloader.java
# Copying 6153c3a9decb8a6cda6c1528408e46e0_1.java → good/AbsDisposalErrorEventListener.java
# Copying 8aa4e455406d2467b9b73cb4dc01a588_4.java → good/UIControl.java
# Copying a43130a156d951349ca5fd0558fb694f_0.java → good/MyCompletableFuture.java
# Copying 97f4066690f332e65c0c59081ce34a65_1.java → good/FeignConfiguration.java
# Copying f8c40f25c1b90ae292fb2c14c10105c3_5.java → good/ClientConnectedEventHandler.java
# Copying 647e11603eb0a1e50f8ebf584233e85a_0.java → good/SentimentMapper.java
# Copying 2e029c780153cb28c1a49775c4ee2431_3.java → good/EtatMarche.java
# Copying 3e3d70087d41e287d2a59a610335f5d9_0.java → good/Acquaintance.java
# Copying 315a2ecee52cb495c531573c1435a9f0_3.java → good/YourPageClass.java
# Copying b2ed29c2c1d98d14466688c944ef193c_4.java → good/Billboard.java
# Copying 1946f8753e9eaed67feba2259cf19a42_11.java → good/LocalDateTimeUtil.java
# Copying d027fa4f5d534117fc9a098ba4696ce6_10.java → good/Auteur.java
# Copying 3d144df16902213aff70fc5650044920_3.java → good/AccountService.java
# Copying 2331084ee1929cfb1917c3dbb14d378c_15.java → good/Calculadora.java
# Copying 34b2b3a994d036ccda796e148a796f96_2.java → good/NumberCurrencyValueInt.java
# Copying 9eac875e86872edb0679ee4c9e05abbb_3.java → good/CustomResponseErrorHandler.java
# Copying 811f48c598873a23318c9a80465737bc_19.java → good/BaseEntity.java
# Copying 615667285fdf29751ec6d4b5ef4f9543_11.java → good/AuthServerConfig.java
# Copying acc6a51fe8c3d7a23af00af9f3816875_0.java → good/WrongQuestionBank.java
# Copying d802418aaa897ccf0baa37c751bb2ae8_2.java → good/QueryAdapter.java
# Copying 6021c1486aae7c72e3db49865c92d161_2.java → good/Imprimante.java
# Copying 24bb9c4172421279b6954e5959209faa_2.java → good/SubscriptionManager.java
# Copying 16b9c67f2e89391345b7888a3f4bb8ce_2.java → good/SQLiteDialectWithLocalDateTime.java
# Copying 7937b7ec0ddda4182ea476ebab996f9a_3.java → good/Event.java
# Copying 75f3f5b5d856e865554db10bd72f2d9b_0.java → good/BatteryLowReceiver.java
# Copying d846114f9b649c77869fc0ff172fa06d_0.java → good/Tire.java
# Copying 4021787b35b26d1ebda665b49fd268f3_10.java → good/RelationshipEdge.java
# Copying 53b766371f025df10cbb38be1e2c6a3b_2.java → good/WeatherBot.java
# Copying d578616152e1f877fc84909163b87d49_5.java → good/Runner.java
# Copying 7fdd45ab2d2c133a9f55f7d1c79332b8_1.java → good/ConcreteHandler1.java
# Copying 17b88be78c84434ccd7d430368db1501_0.java → good/MyJob.java
# Copying c06b9c80220145178ae5bdef9f4c1a3c_7.java → good/PersonSearchController.java
# Copying 37f94aaecd05668a47f4ce13e3702461_1.java → good/Filter.java
# Copying 5ff9b6feab2b8ea9199a5ac6ea8a2245_5.java → good/RepositoryConfig.java
# Copying b82f763c6a6bd6e559b6790b6d933b86_1.java → good/LongToStringSerializer.java
# Copying 576dd8afd09f4d4e979bb3cefe548445_10.java → good/ReservationRepository.java
# Copying a6b961a8d9268b352adad3df7f48cb0d_14.java → good/GrpcAspect.java
# Copying 187a303178ee56917c211123bc90d2a9_5.java → good/WebSocketReceive.java
# Copying 05fc15d66dc975acdff461b043dff863_1.java → good/ShutdownBean.java
# Copying 2ffb79f0b154eec5a7e7135f6aaea368_0.java → good/TenLop.java
# Copying ba53d7ea5c0d5fe9b219c54c1c8fe62f_6.java → good/NoBlackHeartsPlugin.java
# Copying ced9dcfe39b68693d30c95f422713205_0.java → good/DupeCommandMod.java
# Copying 3b0eba72c12003542a80887fdf281c50_8.java → good/CustomEntity.java
# Copying acf577435e571a9c8f20fd341c08ebfd_7.java → good/LoginServiceFactory.java
# Copying dd66f12a02c7ae3b66ce1583daa81054_2.java → good/GradeTwoExercise.java
# Copying a6b961a8d9268b352adad3df7f48cb0d_0.java → good/OperateInterceptor.java
# Copying efce0a8a504c2b175f31e720f41f41e6_1.java → good/ClientSetup.java
# Copying fcba91e4b4ad35d924006b122f695f8a_10.java → good/SoapEndpoint.java
# Copying a597c7a36bac2562a66439ecdea2063a_6.java → good/PointCoordinate.java
# Copying dcbae9d3291b00a4ad7ae3656120c2e9_5.java → good/SomeClass.java
# Copying e36b9d761a7f5d99dc4bb3bdb60011b2_0.java → good/ExampleTest.java
# Copying 3bc88a0067cb5731ce110694e9f120c6_12.java → good/CustomEventPublisher.java
# Copying 893b7691ca78e58e2a751117841a617b_0.java → good/LongPollingController.java
# Copying 28087626db81a45945b619bd6da48d54_5.java → good/Csapat.java
# Copying 6bd3e2631c0c6e44b3d3342cb43d615f_0.java → good/DynamicInvocationHandler.java
# Copying 14aadd7d779c7f2d5cf6a2b6659d4524_0.java → good/MultiValueToAngleConverter.java
# Copying 1d7fbbdadc53b41aa8fdc9de1148b786_4.java → good/DBUtil.java
# Copying d3aa5c446c776a177c4f46a575eb1489_1.java → good/GestorNoticias.java
# Copying 24bb9c4172421279b6954e5959209faa_1.java → good/Package.java
# Copying ba23d5af94abf7120cc89d2927bdd802_0.java → good/ThirdClass.java
# Copying 2c16724a3edd494d452cfb3ad8190336_3.java → good/FirstForm.java
# Copying 51d10b96f69f1f18c7cbdb3869ea5379_2.java → good/CommandSK.java
# Copying f934b413257e52ace9066adea3c54b3b_8.java → good/Accesorio.java
# Copying 592dde17e44503b677286d6f6822ea59_6.java → good/AdminECommand.java
# Copying 77b7ea491d0643494a5a9a994ab69618_1.java → good/RecursiveExample.java
# Copying d5ffdf695700932a7fc001e2ca23e312_12.java → good/CNDailyKHashIndexDto.java
# Copying b5887df6a36199e6648c7848862df5a8_1.java → good/Engine.java
# Copying cf9f6e1a409cca9f55142d6a624c3b8c_7.java → good/ApprovalProcessController.java
# Copying b5fb84532b45e9fa27639336005fad8e_2.java → good/Knight.java
# Copying d3aa5c446c776a177c4f46a575eb1489_0.java → good/Noticia.java
# Copying ce4af154ca287ef6d4e1a2774b2f72c4_0.java → good/WorkerThreads.java
# Copying 3d59441e085e19c54efbf7a0e0896946_1.java → good/TwoWeekLessonAdapter.java
# Copying 26bd282ddcac877f6aef97e26883db38_11.java → good/BankBAdapterStrategy.java
# Copying 3eba49021a441f5ae45e8b253fe84b5c_10.java → good/PostService.java
# Copying cbabcba2f499c10cea4cf86a30884a9b_1.java → good/LoginLog.java
# Copying 3c98aa4edcb6591b9b3f56469870fd09_0.java → good/ProductoDao.java
# Copying 3b9881963a95d533ca7c014f99d26b42_4.java → good/CustomAuthenticationSuccessHandler.java
# Copying 8d466d6d4343bd2ba1aeba6947ddc94f_4.java → good/DataClass.java
# Copying 21d736bf29bd2462c1ddd3e8d89f975b_5.java → good/DatabaseDataWriter.java
# Copying 2aa2fc071fee380cde7dff863d5a69c8_7.java → good/AsyncService.java
# Copying 0aabb229a6394aeab8e22dc1ac67d92a_8.java → good/MyDynamicBeanRegistrar.java
# Copying e1b1074bca3bb5073a2e1645bc2790b7_7.java → good/Entity.java
# Copying 4c0ef5c6a7a848d6b223acc403e6d8e1_6.java → good/YourWebMvcConfigurer.java
# Copying 9f58eafcdfad396117067beb5efdd898_2.java → good/CustomAdapter.java
# Copying d027fa4f5d534117fc9a098ba4696ce6_9.java → good/Groupe.java
# Copying 94af5a22f5ad421fdc17ae600cfd42f4_0.java → good/BinarySearchTree.java
# Copying a984f6d13d811ad803e4f7e87a1b46c7_6.java → good/Desktop.java
# Copying 4389c2eacf3455bec803e9cbb848cb78_14.java → good/WS02.java
# Copying 094e48c8ce412f7d32a7c7ba4d13bda0_0.java → good/CompteBancaire.java
# Copying 25b153b1fad8befbb470e28fcee3c464_31.java → good/ArticleService.java
# Copying cba9560704d31262fec73ed6935a5be6_1.java → good/MarkdownUtils.java
# Copying 9de571993d5559c688f57485eb2002c1_5.java → good/CustomFluidContainerBlock.java
# Copying e591576ffa2d6ea131d431c2857d4d53_10.java → good/GroupData.java
# Copying df9fa9a581508aa7dd9e405dea37ea91_5.java → good/MyReceiver.java
# Copying bda59c594f0c7a492479a43c3368fc1c_6.java → good/Buyer.java
# Copying aeef68159306ca843aeaf53ef52a3d63_15.java → good/TokenResponse.java
# Copying 5658f3cce3148a9c23f30ad16f21c486_7.java → good/BankDataHandlerContext.java
# Copying a597c7a36bac2562a66439ecdea2063a_8.java → good/SourcePointPartitioner.java
# Copying 48d879041f8715511819ccbfbef9bc05_3.java → good/BlockProtectMod.java
# Copying dfa6a6b551db63b15f7ae84eff714e54_1.java → good/AdidasArmorPlugin.java
# Copying 5c1d2b164f1c5bdfad721f12e6ccd1fe_0.java → good/CalculatorActivity.java
# Copying 597cde707179ea61005cefb7fd96a697_11.java → good/ApiDocumentationTest.java
# Copying 9610f5aaa2e01f4d80cbf4c3570ae4d4_8.java → good/PopupWrapperFactory.java
# Copying c2edf8185a4850f3c96a27f41723a1ee_0.java → good/InvestmentCost.java
# Copying 48232d5675b7c1a9b20a7f2c02e3ce9b_1.java → good/KlasaGlownaRepository.java
# Copying 4b924b8b1413df15ab696650067ede8f_1.java → good/PlayerDataLoader.java
# Copying 621f1403352dbf0842885643a3a12f9c_3.java → good/MyTimeObject.java
# Copying a637cd573b2c92bb52780311a728a1d8_21.java → good/BuyMenu.java
# Copying ed03cc5f28c6562f2e5c5e8f054a17da_0.java → good/MyStatelessBean.java
# Copying 9eac875e86872edb0679ee4c9e05abbb_8.java → good/MyResponseEntity.java
# Copying e7a1756a2bf8b05459dd65bcd2cdd949_0.java → good/MyRepository.java
# Copying da10c5f400aac124d48c070c6155e8db_4.java → good/WebSocketMessageHandler.java
# Copying d5e8283728be82fe2a77ad63a11e5c42_12.java → good/InicioServlet.java
# Copying f840e733f504af847f9ac789d7548665_1.java → good/NewsRepository.java
# Copying a1ea4a0fe7587044cb3937c282a13f39_2.java → good/GUIExample.java
# Copying e75907695c53dbdd7ef2c855598f410a_1.java → good/JobOne.java
# Copying 7279de223c60f73c0431bbb07f602d60_3.java → good/BmiController.java
# Copying e543d4261299cc693378a104da46db5b_8.java → good/DubboReferenceBeanRegistrar.java
# Copying d578616152e1f877fc84909163b87d49_4.java → good/Athlete.java
# Copying 409de150de674e7a0f194b187566b1ca_2.java → good/Tower.java
# Copying cedb1ffef03a12b2783d66e5920c1405_8.java → good/AuthenticationController.java
# Copying ab09eef5d14bac1a1ff761a7d77a07c1_1.java → good/QuizService.java
# Copying dd55b21c49458aa5f0c7ca820368e1fe_1.java → good/KafkaProcessor.java
# Copying 0f407e230b3e7372df4f761988374ce4_0.java → good/MatrixRotation.java
# Copying c213d6295b673654618633274542db76_1.java → good/HttpStatusConfiguration.java
# Copying c37dd8ebd69da041af1f09091461e5a1_1.java → good/AngleConverter.java
# Copying fe8be41f8d6634e9f4315f1126241604_2.java → good/StudentGradeAnalyzer.java
# Copying 1dcc03b2ea626e21407969cf11bb7541_1.java → good/FoldersListAdapter.java
# Copying 1e69f4eb482d69799f67df96136ebd58_7.java → good/LCSProgram.java
# Copying 798d4bb61acdb6e5315baebe5a57636e_1.java → good/HttpsConfig.java
# Copying df4033d2228baad9cd0f26b2179c188c_9.java → good/Categoria.java
# Copying 6e9a61175a024096c0abc782afbc0946_1.java → good/TextAnalyzer.java
# Copying e565dc32cb9899871ef336da3fbf692f_1.java → good/MyPlaceholderHook.java
# Copying 4c3814b5db7fdab0e270e8467153f69d_0.java → good/MailSender.java
# Copying 5fae9a190918e1fed1ce7573144dd295_0.java → good/ArrayParityException.java
# Copying 1c1a79c7603d3969e1b898e03245e418_36.java → good/ClassNameModifier.java
# Copying fa1306ea7b3f5bd1cc7c0093db78df61_5.java → good/MainWindow.java
# Copying 68a087db33864e8c492e4d865a4d9bd4_1.java → good/BatteryMonitorService.java
# Copying 3b0eba72c12003542a80887fdf281c50_3.java → good/YourModClient.java
# Copying 2b1af74392928dd7ea66555f92db1dd7_3.java → good/Control.java
# Copying fb00a38e9a6f6c7b49d1b674efe73cf7_0.java → good/CharacterFilter.java
# Copying 9bb7d4d816527ad6072dfc778e9bef75_0.java → good/IPRange.java
# Copying 79fc4b73adc00d0a942084b3212d5b68_5.java → good/BottomTextButton.java
# Copying 06882404b7f259ba8fbbe41875ea5314_20.java → good/RestClientConfig.java
# Copying 9beaed529aa81d3a2fc85f07a93b6961_9.java → good/MyCacheEvictMethodInterceptor.java
# Copying 30b37cffe00be4506dbebe9726fa13d9_3.java → good/RoomService.java
# Copying ce4eb5348b6015b6f8437555a5a0c22a_1.java → good/YourModEventSubscriber.java
# Copying cb8b14bc74bba5457f50f56bf315659d_2.java → good/LoginSteps.java
# Copying 0f012095d7e6a973549887f2cd5326fe_12.java → good/ItemsProcessing.java
# Copying f787e5a6a864afa653c2905cc1d7ca25_37.java → good/LorentzianDistanceStrategy.java
# Copying 4c4385152e36f0a08b1eb35d22163836_2.java → good/GoodsCatalogController.java
# Copying 3601113c6074110c673d0667e7cd067b_0.java → good/MovingDots.java
# Copying 8aa4e455406d2467b9b73cb4dc01a588_2.java → good/PuzzleElement.java
# Copying 576dd8afd09f4d4e979bb3cefe548445_12.java → good/VoyageRepository.java
# Copying bbc14c99b435054a30e74127147f2468_1.java → good/Packet56MapChunkBulk.java
# Copying 934b8bdc83645099fba942ea9ce087bb_2.java → good/JwtTokenProvider.java
# Copying 2e0c8a7a3ec498bcf8ad1382f8631025_5.java → good/Main2Activity.java
# Copying d7d6913e0d8eb2c2d2d955324e922b43_0.java → good/MultiDirectionalMovement.java
# Copying 9e7871ef23abed3f5f42012ef2d46314_4.java → good/Money.java
# Copying fbde65ad70ebceba2daacf8f9d9b20aa_14.java → good/SentryConfiguration.java
# Copying 6b0535bc8b0dfdfa32a9fa40b92614e0_5.java → good/QrCodeScanner.java
# Copying 4c7abe893143fd226486c8fc82065fcc_10.java → good/SkinDataParserV2.java
# Copying 34307da60a3369de314894922c918acd_1.java → good/PeliculaRest.java
# Copying 9ed52d4167dac276bc0b0af265a88467_0.java → good/TemperatureComparisonServlet.java
# Copying c43555b54891b848326cc2377eb5bd0d_10.java → good/PermissionRequirement.java
# Copying 80109a5f2afc53b0ba01b8e5e81d6a41_0.java → good/OpenApiGenerator.java
# Copying f9b102ad54a8fbbae09727dac3cef546_1.java → good/PagesController.java
# Copying 9e7871ef23abed3f5f42012ef2d46314_2.java → good/Currency.java
# Copying 0a48b63f38e7992b54ed64a5f732f2ef_4.java → good/JwtRequestFilter.java
# Copying 6b131868895dcd5d4aac33f7bf959707_0.java → good/Provider.java
# Copying a9fa0f8e0ce21271ada43f95fe6b3dc2_3.java → good/FhirServerConfiguration.java
# Copying be1c3072848f60b2d81379c2b05a2a82_1.java → good/ListNode.java
# Copying 8887c89a24d42cb73df48894dea548e9_1.java → good/PluginManager.java
# Copying d34d07c4b5d8b8a73a4fcc9c5ca5d5c8_3.java → good/TokenController.java
# Copying 050299bb235952046ca35c8ae501af46_8.java → good/AvoidWaterAndFollowPlayerGoal.java

# %%
directory = "files/java/codes/good"
output_file = "results/java_lint.json"
os.makedirs(os.path.dirname(output_file), exist_ok=True)

java_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith(".java")]
all_results = []

os.makedirs("/tmp/java_linting", exist_ok=True)

class_files = [f for f in os.listdir(directory) if f.endswith(".java")]

hash_to_original = mapping  # hash -> original filename

hash_to_classfile = {}



def hash_file_content(path):
    hasher = hashlib.sha256()
    with open(path, "rb") as f:
        while chunk := f.read(8192):
            hasher.update(chunk)
    return hasher.hexdigest()

class_to_original = {}

for class_filename in class_files:
    class_filepath = os.path.join(directory, class_filename)
    file_hash = hash_file_content(class_filepath)
    original = hash_to_original.get(file_hash, None)
    if original:
        class_to_original[class_filename] = original
    else:
        # fallback: map to itself if no mapping found
        class_to_original[class_filename] = class_filename

def add_error(file, errors):
    base = os.path.basename(file)
    original_filename = class_to_original.get(base, base)  # fallback to base

    if errors:
        all_results.append({
            "type": "syntax-error",
            "module": os.path.basename(original_filename) if original_filename else "unknown",
            "obj": "",
            "line": None,
            "column": None,
            "path": original_filename if original_filename else "",
            "symbol": "syntax-error",
            "message": "\n".join(errors),
            "message-id": "",
        })

result = subprocess.run(
    ["javac", "-d", "/tmp/java_linting", *java_files],
    capture_output=True,
    text=True,
)

if result.returncode != 0:
    current_file = None
    current_errors = []

    for line in result.stderr.splitlines():
        if ".java:" in line and "error:" in line:
            if current_file is not None:
                add_error(current_file, current_errors)
            current_errors = [line]
            current_file = line.split(":")[0]
        else:
            current_errors.append(line)
    if current_file is not None:
        add_error(current_file, current_errors)

with open(output_file, "w") as f:
    json.dump(all_results, f, indent=2)

# %% [markdown]
# ### C

# %%
# Setup directories
directory = "files/c/codes/"
output_file = "results/c_lint.json"
os.makedirs(os.path.dirname(output_file), exist_ok=True)

# Gather all .c files
c_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith(".c")]
all_results = []

# Run GCC in syntax-only mode on all files
result = subprocess.run(
    ["gcc", "-fsyntax-only", *c_files],
    capture_output=True,
    text=True,
)

# Parse output if there were errors
if result.returncode != 0:
    for line in result.stderr.splitlines():
        if ": error:" in line:
            parts = line.split(":")
            file_path = parts[0]
            line_no = int(parts[1]) if parts[1].isdigit() else None
            column_no = int(parts[2]) if parts[2].isdigit() else None
            message = line.split(": error:")[1].strip()
            
            # Decode any unicode punctuation to ASCII equivalents
            message = message.replace("\u2018", "'").replace("\u2019", "'")
            
            all_results.append({
                "type": "syntax-error",
                "module": os.path.basename(file_path),
                "obj": "",
                "line": line_no,
                "column": column_no,
                "path": file_path,
                "symbol": "syntax-error",
                "message": message,
                "message-id": "",
            })

# Write results to file
with open(output_file, "w") as f:
    json.dump(all_results, f, indent=2)

# %% [markdown]
# ### PHP

# %%
# Setup directories
directory = "files/php/codes/"
output_file = "results/php_lint.json"
os.makedirs(os.path.dirname(output_file), exist_ok=True)

# Gather all .php files
php_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.endswith(".php")]
all_results = []

for file in php_files:
    with open(file, "r", encoding="utf-8") as f:
        raw = f.read()
        if "<?php" not in raw:
            all_results.append({
            "type": "syntax-error",
            "module": os.path.basename(file),
            "obj": "",
            "line": None,
            "column": None,
            "path": file,
            "symbol": "Not valid php file",
            "message": "The file does not include <?php tag",
            "message-id": "",
            })
            continue      
            
    result = subprocess.run(
        ["php", "-l", file],
        capture_output=True,
        text=True
    )
    if "Parse error" in result.stdout or "Parse error" in result.stderr:
        match = re.search(r'PHP Parse error: (.+) in .+ on line (\d+)', result.stdout)
        if match:
            message = match.group(1)
            line_no = int(match.group(2))
        else:
            message = result.stdout.strip()
            line_no = 0
        
        all_results.append({
            "type": "syntax-error",
            "module": os.path.basename(file),
            "obj": "",
            "line": line_no,
            "column": None,
            "path": file,
            "symbol": "syntax-error",
            "message": result.stderr + result.stdout,
            "message-id": "",
        })

# Write results to file
with open(output_file, "w") as f:
    json.dump(all_results, f, indent=2)

# %% [markdown]
# ### C#

# %%
import os
import json
import subprocess
from tqdm import tqdm

# Setup directories
directory = "files/csharp/codes/"
output_file = "results/csharp_lint.json"
os.makedirs(os.path.dirname(output_file), exist_ok=True)

# Gather all .cs files
csharp_files = [
    os.path.join(directory, f)
    for f in os.listdir(directory)
    if f.endswith(".cs")
]

all_results = []
batch_size = 500   # tune this as needed (100–1000 is good)

def chunked(lst, size):
    for i in range(0, len(lst), size):
        yield lst[i:i+size]

# Add tqdm for progress
for batch in tqdm(list(chunked(csharp_files, batch_size)), desc="Checking C# files"):
    result = subprocess.run(
        ["dotnet", "script", "utils/SyntaxCheck.csx", *batch],
        capture_output=True,
        text=True
    )

    try:
        batch_results = json.loads(result.stdout)
        all_results.extend(batch_results)
    except json.JSONDecodeError:
        all_results.append({
            "type": "syntax-error",
            "module": "batch",
            "obj": "",
            "line": None,
            "column": None,
            "path": None,
            "symbol": "syntax-error",
            "message": result.stderr + result.stdout,
            "message-id": "",
        })

print(f"Collected {len(all_results)} results")

# Save results
with open(output_file, "w") as f:
    json.dump(all_results, f, indent=2)
# Out:
# Checking C# files:   0%|          | 0/28 [00:00<?, ?it/s]
# Checking C# files: 100%|██████████| 28/28 [00:23<00:00,  1.19it/s]
# Collected 56798 results
