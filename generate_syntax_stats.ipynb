# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
from pandas import DataFrame
from datasets import load_dataset as hf_load_dataset
import json

from sentence_transformers import SentenceTransformer
from sklearn.cluster import AgglomerativeClustering
import re
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
from sklearn.cluster import MiniBatchKMeans
from collections import defaultdict

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
linting_paths = {
    "php": "results/php_lint.json",
    "csharp": "results/csharp_lint.json",
    "python": "results/python_lint.json",
    "c": "results/c_lint.json",
    "javascript": "results/js_lint.json",
    "java": "results/java_lint.json",
}

# %%
other_cleaned = []
with open("other_cleaned.json", "r", encoding="utf-8") as f:
    for line in f.readlines():
        other_cleaned.append(json.loads(line))

# %%
tracker = {
    "php": 0,
    "csharp": 0,
    "python": 0,
    "c": 0,
    "javascript": 0,
    "java": 0,
}
for row in other_cleaned:
    language = row["language"].lower()
    if language == "c++":
        language = "c"
    elif language == "c#":
        language = "csharp"
    if language not in tracker.keys():
        continue
    tracker[language] += 1


print(tracker)
# Out:
# {'php': 1935, 'csharp': 13893, 'python': 57371, 'c': 21510, 'javascript': 26442, 'java': 19257}

# %%
linting_results = {}

for key, value in linting_paths.items():
    with open(value, "r", encoding="utf-8") as f:
        linting_results[key] = json.load(f)

# %%
for key, value in linting_results.items():
    hashes = set()
    for row in value:
        hashes.add(row["module"])
    print(key, len(hashes))
# Out:
# php 1935
# csharp 6517
# python 19805
# c 18323
# javascript 15725
# java 20

# %%
messages = []

for key, value in linting_results.items():
    for row in value:
        convo_hash = row["module"].split("_")[0]
        messages.append(row["message"])

# %%
model = SentenceTransformer("all-MiniLM-L6-v2", backend="openvino")
# Out:
# /home/pooria/code_analysis_uqo/venv/lib/python3.10/site-packages/torch/onnx/_internal/registration.py:162: OnnxExporterWarning: Symbolic function 'aten::scaled_dot_product_attention' already registered for opset 14. Replacing the existing function with new function. This is unexpected. Please report it on https://github.com/pytorch/pytorch/issues.
#   warnings.warn(
# Multiple OpenVINO files found in 'sentence-transformers/all-MiniLM-L6-v2': ['openvino/openvino_model.xml', 'openvino/openvino_model_qint8_quantized.xml'], defaulting to 'openvino/openvino_model.xml'. Please specify the desired file name via `model_kwargs={"file_name": "<file_name>"}`.

# %%
# Step 1: embed raw messages
embeddings = model.encode(messages, batch_size = 128)
np.save("tmp/embeddings.npy", embeddings)

# %%
embeddings[0]

# %%
embeddings = np.load("tmp/embeddings.npy")

# %%
error_categories = []
with open("utils/error_categories.json", "r", encoding="utf-8") as f:
    error_categories = json.load(f)

# %%
len(error_categories)
# Out:
# 20

# %%
error_category_embeddings = {}
for error_category in error_categories:
    
    description = error_category["description"]
    embedding = model.encode([description])
    error_category_embeddings[error_category["category"]] = embedding

# %%
# Cosine similarity algorithm on the categories vs error messages

# %%
categories = list(error_category_embeddings.keys())
category_matrix = np.vstack([error_category_embeddings[c] for c in categories])

similarity = cosine_similarity(embeddings, category_matrix)

print(similarity.shape)

best_indices = np.argmax(similarity, axis=1)
best_categories = [categories[idx] for idx in best_indices]

results = []
for msg, cat_idx in zip(messages, best_indices):
    results.append({"message": msg, "predicted_category": categories[cat_idx]})
# Out:
# (177732, 20)
# {'message': '; expected', 'predicted_category': 'Syntax Error'}

# %%
import random

# Step 1: assign each message to its best category, carrying the language key
category_to_lang_msgs = defaultdict(lambda: defaultdict(list))

# Flatten but keep language info
all_rows = []
for lang, rows in linting_results.items():
    for row, cat in zip(rows, best_categories[:len(rows)]):  
        # make sure alignment between rows and best_categories is correct
        all_rows.append((lang, row["message"], cat))

# Group into category → language → messages
for lang, msg, cat in all_rows:
    category_to_lang_msgs[cat][lang].append(msg)

# Step 2: sort categories by number of total messages
sorted_categories = sorted(
    category_to_lang_msgs.items(),
    key=lambda x: sum(len(msgs) for msgs in x[1].values()),
    reverse=True
)

# Step 3: pretty print with language distributions + random samples
for cat, lang_dict in sorted_categories:
    total_msgs = sum(len(msgs) for msgs in lang_dict.values())
    print(f"\nCategory {cat} ({total_msgs} messages):")
    
    for lang, msgs in sorted(lang_dict.items(), key=lambda x: len(x[1]), reverse=True):
        print(f"  Language {lang}: {len(msgs)} messages")
        sample_msgs = random.sample(msgs, min(5, len(msgs)))
        for m in sample_msgs:
            print("    -", m.replace("\n", " ")[:120], "...")
# Out:
# Category Syntax Error (95432 messages):
#   Language c: 48598 messages
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '.' token ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before 'приведет' ...
#     - unknown type name 'address' ...
#     - expected declaration specifiers or '...' before '&' token ...
#     - unknown type name 'обеспечение' ...
#   Language csharp: 30032 messages
#     - A get or set accessor expected ...
#     - Identifier expected ...
#     - ) expected ...
#     - Invalid token '=' in class, record, struct, or interface member declaration ...
#     - ; expected ...
#   Language python: 9585 messages
#     - invalid syntax (3dca8fb089f4ba02cab912b049b5edeb_4.py, line 1) ...
#     - invalid syntax (662358933687754f576696979835b325_8.py, line 1) ...
#     - invalid syntax (4af4d025fe2c5f1ba5802ac8f6d564ad_0.py, line 1) ...
#     - invalid syntax (ff481342352594d81e5c3bfca838a604_0.py, line 1) ...
#     - invalid syntax (a08540dcc16a8788a10bc8f0ccc2a0f5_2.py, line 1) ...
#   Language javascript: 7217 messages
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token ...
#     - Parsing error: Unexpected token < ...
#
# Category Declaration Error (33026 messages):
#   Language c: 15683 messages
#     - unknown type name 'size_t' ...
#     - 'ETH_P_ALL' undeclared here (not in a function) ...
#     - expected identifier or '(' before '<' token ...
#     - expected identifier or '(' before 'while' ...
#     - 'pi' undeclared here (not in a function) ...
#   Language csharp: 11013 messages
#     - Invalid token ':' in class, record, struct, or interface member declaration ...
#     - Syntax error, ',' expected ...
#     - } expected ...
#     - The modifier 'private' is not valid for this item ...
#     - An add or remove accessor expected ...
#   Language python: 3529 messages
#     - invalid syntax (dc0973a89a20b69d12764694274c7b9f_34.py, line 1) ...
#     - invalid syntax (95f77894430ac1abf27838408adb91fe_1.py, line 1) ...
#     - invalid syntax (06cced611e2f9c58d6243bbcb6871efd_6.py, line 1) ...
#     - invalid syntax (2e6383b0eb9950a2131a9ed0e7dbeba2_0.py, line 1) ...
#     - invalid syntax (9e95173da52c443646e879ac288bdb8d_9.py, line 1) ...
#   Language javascript: 2801 messages
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token HTTP ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: 'return' outside of function ...
#
# Category Access Control Error (20852 messages):
#   Language c: 8106 messages
#     - expected identifier or '(' before '%' token ...
#     - 'CAM_PIN_D4' undeclared (first use in this function) ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before 'character' ...
#     - expected declaration specifiers or '...' before '\x53697a65' ...
#     - expected identifier or '(' before '%' token ...
#   Language csharp: 7837 messages
#     - Unexpected character sequence '...' ...
#     - ; expected ...
#     - Invalid expression term '/' ...
#     - Syntax error, '(' expected ...
#     - Identifier expected ...
#   Language python: 2741 messages
#     - invalid syntax (67f288df3b69b6e3a88e117dc3c93249_8.py, line 1) ...
#     - invalid syntax (c084c1a76c27d04816c44f9c278220d0_1.py, line 1) ...
#     - invalid syntax (d1a5c31b8b98704b37b8b95cfc26de7d_5.py, line 1) ...
#     - invalid syntax (ab483c693fcd49fdc1cacf623debdca4_52.py, line 1) ...
#     - invalid syntax (bcb274b104a60384823e0d97934bd9d5_3.py, line 1) ...
#   Language javascript: 2168 messages
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected character '@' ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token : ...
#
# Category Preprocessor Error (18377 messages):
#   Language c: 5390 messages
#     - unknown type name 'IS' ...
#     - expected identifier or '(' before '%' token ...
#     - expected expression before ')' token ...
#     - expected identifier or '(' before '%' token ...
#     - called object 'vel' is not a function or function pointer ...
#   Language csharp: 5172 messages
#     - Tuple must contain at least two elements. ...
#     - ; expected ...
#     - } expected ...
#     - A namespace cannot directly contain members such as fields, methods or statements ...
#     - Invalid token '+' in class, record, struct, or interface member declaration ...
#   Language python: 3021 messages
#     - invalid syntax (360e47f8eaee87e461b38dfa439b2769_0.py, line 1) ...
#     - invalid syntax (b450a43edb2de68bc5aaa2471ec08097_0.py, line 1) ...
#     - invalid syntax (098bc49b46b42a16213692007e7a0aee_27.py, line 1) ...
#     - invalid syntax (1d224e731a428f1e161e3bdf17a29ebd_2.py, line 1) ...
#     - invalid syntax (d170c84585cca2008107e2e9f53b2bbe_5.py, line 1) ...
#   Language javascript: 2759 messages
#     - Parsing error: Unexpected token animationController ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token { ...
#     - Parsing error: Unexpected token var ...
#     - Parsing error: Unexpected token < ...
#   Language php: 1935 messages
#     - The file does not include <?php tag ...
#     - The file does not include <?php tag ...
#     - The file does not include <?php tag ...
#     - The file does not include <?php tag ...
#     - The file does not include <?php tag ...
#   Language java: 100 messages
#     - files/java/codes/good/HPChangeBuffEffectHandler.java:9: error: '{' expected public class AttackPowerChangeBuffEffectHand ...
#     - files/java/codes/good/TimeEntry.java:13: error: not a statement         get { return _minutes / 60.0; }          ^ ...
#     - files/java/codes/good/KeyFramesExtractor.java:6: error: class, interface, enum, or record expected     public bool InPro ...
#     - files/java/codes/good/KeyFramesExtractor.java:5: error: class, interface, enum, or record expected     public List<long> ...
#     - files/java/codes/good/SwipeControls.java:1: error: '{' expected public class SwipeControls : MonoBehaviour               ...
#
# Category Lexical Error (2829 messages):
#   Language c: 1244 messages
#     - expected identifier or '(' before '%' token ...
#     - expected expression before '::' token ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before 'S_RREQ' ...
#     - invalid suffix "F" on integer constant ...
#     - expected ',' or ';' before 'RUN' ...
#   Language csharp: 885 messages
#     - Syntax error, ',' expected ...
#     - Keyword, identifier, or string expected after verbatim specifier: @ ...
#     - Identifier expected ...
#     - Invalid expression term '/' ...
#     - Type or namespace definition, or end-of-file expected ...
#   Language python: 377 messages
#     - invalid syntax (dd3136f022ff7d34fe5c42a03a9f7c51_2.py, line 1) ...
#     - unexpected indent (966e4eebc5853779e8c513b1f3423c1f_0.py, line 2) ...
#     - invalid syntax (91ac167d2139f7004248036e1430b5e5_0.py, line 1) ...
#     - unterminated string literal (detected at line 3) (3a19d137fd175086897d877ce357b173_1.py, line 3) ...
#     - invalid syntax (f291b8c34891d6085c89adb97d9c7885_4.py, line 1) ...
#   Language javascript: 323 messages
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token topMargin ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected character '@' ...
#     - Parsing error: Unexpected character '├' ...
#
# Category Type Error (2447 messages):
#   Language c: 1398 messages
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '::' token ...
#     - variable 'my_driver' has initializer but incomplete type ...
#     - expected identifier or '(' before 'if' ...
#     - expected identifier or '(' before '<' token ...
#     - expected identifier or '(' before 'case' ...
#   Language csharp: 650 messages
#     - { expected ...
#     - Type or namespace definition, or end-of-file expected ...
#     - The modifier 'private' is not valid for this item ...
#     - ; expected ...
#     - Syntax error, ',' expected ...
#   Language python: 215 messages
#     - expected an indented block after 'if' statement on line 5 (f6d6df0cf73ea757f905e2b1921fda85_6.py, line 6) ...
#     - invalid syntax (4b4feca5517c71717b14d459b6e08a9f_0.py, line 1) ...
#     - invalid syntax (3d109b7722a03534c125b59ca8610121_8.py, line 1) ...
#     - invalid syntax (27f89f910c2bc364afbd8b35fc411ac3_0.py, line 1) ...
#     - invalid syntax (d3bc8b7ae1a615d9400e9c76230ac220_1.py, line 1) ...
#   Language javascript: 184 messages
#     - Parsing error: Unexpected character ' ' ...
#     - Parsing error: Unexpected token % ...
#     - Parsing error: Unexpected token : ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#
# Category Function Signature Mismatch (1538 messages):
#   Language c: 879 messages
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '++' token ...
#     - invalid preprocessing directive #\U00005b9a\U00004e49\U00004e24\U00004e2a\U00005b57\U00007b26\U00004e32 ...
#     - expected identifier or '(' before '<' token ...
#     - invalid use of undefined type 'struct proc' ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '++' token ...
#   Language csharp: 422 messages
#     - A get or set accessor expected ...
#     - The modifier 'private' is not valid for this item ...
#     - A get or set accessor expected ...
#     - A get or set accessor expected ...
#     - Invalid expression term '/' ...
#   Language python: 130 messages
#     - invalid syntax (0af4e0c92d157f2981f293cb7404a8b3_17.py, line 1) ...
#     - invalid syntax (458082302a56f159fe2fcf8037cdd688_6.py, line 1) ...
#     - invalid syntax (7b6013c07b3936ac0044473a54b8d7a1_2.py, line 1) ...
#     - invalid syntax (cb6e294d59f68831eb7118edc84d0db8_0.py, line 1) ...
#     - 'await' outside function (38bbe4fa036fb75db5323f10294c8b66_2.py, line 32) ...
#   Language javascript: 107 messages
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token install ...
#     - Parsing error: Unexpected token . ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#
# Category Const Correctness Error (1190 messages):
#   Language c: 587 messages
#     - unknown type name 'class' ...
#     - expected identifier or '(' before '.' token ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '++' token ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '.' token ...
#     - initializer element is not constant ...
#   Language csharp: 395 messages
#     - ; expected ...
#     - Invalid expression term '<' ...
#     - Preprocessor directives must appear as the first non-whitespace character on a line ...
#     - A get or set accessor expected ...
#     - ; expected ...
#   Language python: 112 messages
#     - invalid syntax. Perhaps you forgot a comma? (997825e4fbeee18e4dd6dc2c7d147671_0.py, line 1) ...
#     - invalid syntax (1c43c362b186f4e4b178fb7317123aa5_3.py, line 1) ...
#     - invalid syntax (d7b7db8ee6688b044870e57ca9d73931_10.py, line 1) ...
#     - unexpected indent (bddd2edd46282790c198ac1013c7cb93_2.py, line 2) ...
#     - invalid syntax (a2f14f2ba6bac41c5b3be7bf4f3792e7_28.py, line 1) ...
#   Language javascript: 96 messages
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token : ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#
# Category Inheritance Error (462 messages):
#   Language c: 232 messages
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '.' token ...
#     - unknown type name 'uintptr_t' ...
#     - expected identifier or '(' before '[' token ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before 'if' ...
#     - expected declaration specifiers or '...' before '\x28487a29' ...
#   Language csharp: 189 messages
#     - Type expected ...
#     - The modifier 'public' is not valid for this item ...
#     - Type or namespace definition, or end-of-file expected ...
#     - Identifier expected ...
#     - Tuple must contain at least two elements. ...
#   Language python: 28 messages
#     - illegal target for annotation (7515a856f657ad2957bd3c6995d4aee6_2.py, line 1) ...
#     - invalid syntax (778b35862eebbe9ecd0273dfc154d44f_14.py, line 1) ...
#     - invalid syntax (2df92e2463a8dd67f5aa14a6c78a05da_29.py, line 1) ...
#     - invalid syntax (8e664a1bf84c08fd2a2ad1ae0a83a0c2_2.py, line 1) ...
#     - unexpected indent (7120ca6546548cfb5252b6760d80b80d_20.py, line 3) ...
#   Language javascript: 13 messages
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token ] ...
#     - Parsing error: 'return' outside of function ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#
# Category Template/Generics Error (403 messages):
#   Language c: 349 messages
#     - initializer element is not constant ...
#     - invalid preprocessing directive #\U0000041e\U00000441\U00000442\U00000430\U0000043d\U0000043e\U00000432\U00000438\U00000 ...
#     - expected identifier or '(' before '...' token ...
#     - 'OP_BUY' undeclared (first use in this function) ...
#     - initializer element is not constant ...
#   Language csharp: 26 messages
#     - Type expected ...
#     - ; expected ...
#     - Syntax error, ',' expected ...
#     - Expected expression ...
#     - Invalid expression term '/' ...
#   Language python: 15 messages
#     - invalid syntax (da896c2a32db53e0c62106891e21b28b_4.py, line 1) ...
#     - invalid syntax (ab483c693fcd49fdc1cacf623debdca4_5.py, line 1) ...
#     - invalid syntax (0a76ccb1b559fe4a80cc989017ceb529_23.py, line 1) ...
#     - 'await' outside function (a0b658ec85c812088200f3c452d81ed8_0.py, line 1) ...
#     - illegal target for annotation (ef860585ffee5fa17b91aac30cfc5400_3.py, line 2) ...
#   Language javascript: 13 messages
#     - Parsing error: Unexpected token % ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#
# Category Division By Zero (390 messages):
#   Language c: 302 messages
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '::' token ...
#     - expected identifier or '(' before 'case' ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before 'open' ...
#     - unknown type name 'sudo' ...
#     - expected identifier or '(' before '%' token ...
#   Language csharp: 54 messages
#     - Invalid token '+' in class, record, struct, or interface member declaration ...
#     - ; expected ...
#     - ; expected ...
#     - } expected ...
#     - ; expected ...
#   Language python: 19 messages
#     - invalid syntax (5c94193cfd314e9b55a35f2ee3e986dd_16.py, line 1) ...
#     - invalid syntax (8f4e8242de88335b732f0e23144cc1d7_17.py, line 1) ...
#     - invalid syntax (4ba54ac6196a321830c60e1ef0412c8d_0.py, line 1) ...
#     - invalid syntax. Perhaps you forgot a comma? (7f31aa9b6a59320e922b76fe51414ad0_1.py, line 2) ...
#     - invalid syntax (9ed505f0b64626716b6793ad4ed94014_3.py, line 1) ...
#   Language javascript: 15 messages
#     - Parsing error: Unexpected token { ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected keyword 'new' ...
#     - Parsing error: Unexpected token ...
#     - Parsing error: Unexpected token < ...
#
# Category Ambiguity Error (272 messages):
#   Language c: 200 messages
#     - conflicting types for 'closelog'; have 'int()' ...
#     - parameter 'curve' has just a forward declaration ...
#     - invalid suffix "rdparty" on integer constant ...
#     - expected ')' before numeric constant ...
#     - unknown type name 'ExampleStruct'; use 'struct' keyword to refer to the type ...
#   Language csharp: 45 messages
#     - Identifier expected ...
#     - Invalid expression term '=' ...
#     - Invalid token ':' in class, record, struct, or interface member declaration ...
#     - ; expected ...
#     - Keyword 'this' or 'base' expected ...
#   Language python: 15 messages
#     - invalid syntax (1ad52e9bdd05ecfbf85ed028d75134b5_0.py, line 1) ...
#     - invalid syntax (eeaf277128d0cea8d8221529f4d5f90f_8.py, line 1) ...
#     - 'await' outside function (a10f79429fa13eeb115ad5db06229667_1.py, line 2) ...
#     - unexpected indent (5adf078b60e64aa9039b2ed7ebf16cb4_17.py, line 2) ...
#     - invalid syntax (e86a869b578a2e4cc78173a7aea06d1e_2.py, line 1) ...
#   Language javascript: 12 messages
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#
# Category Scope Error (192 messages):
#   Language c: 117 messages
#     - stray '\343' in program ...
#     - 'MODE_MAIN' undeclared (first use in this function) ...
#     - expected ';', ',' or ')' before '<' token ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' at end of input ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before 'nofile' ...
#   Language csharp: 55 messages
#     - Type or namespace definition, or end-of-file expected ...
#     - ; expected ...
#     - ; expected ...
#     - ; expected ...
#     - Identifier expected ...
#   Language python: 10 messages
#     - invalid syntax (0f51f5a86a9fd5469ab423c1690984ac_3.py, line 1) ...
#     - invalid syntax (aef61741fb8b9370ebdfa7925c6f7865_5.py, line 1) ...
#     - invalid syntax (f89294185872b997b69b6586770d0762_0.py, line 1) ...
#     - invalid syntax (e54475a6d026c273d102f085854910fb_2.py, line 1) ...
#     - invalid syntax (6e47e37c5dbbad05e21964d645f840d5_4.py, line 1) ...
#   Language javascript: 10 messages
#     - Parsing error: Unexpected token 'SOFTWARE\Microsoft\Windows NT\CurrentVersion' ...
#     - Parsing error: Unexpected token { ...
#     - Parsing error: Unexpected token const ...
#     - Parsing error: Unexpected token it ...
#     - Parsing error: Unexpected token player ...
#
# Category Initialization Error (176 messages):
#   Language c: 176 messages
#     - 'a_max' undeclared here (not in a function) ...
#     - stray '\' in program ...
#     - redefinition of 'cnt_n' ...
#     - 'screenHeight' undeclared here (not in a function) ...
#     - expected identifier or '(' before 'else' ...
#
# Category Linker Error (104 messages):
#   Language c: 70 messages
#     - redefinition of 'err' ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '.' token ...
#     - expected identifier or '(' before '%' token ...
#     - expected identifier or '(' before 'return' ...
#     - expected ',' or ';' before 'char' ...
#   Language csharp: 20 messages
#     - Invalid expression term 'for' ...
#     - } expected ...
#     - ; expected ...
#     - A get or set accessor expected ...
#     - Preprocessor directives must appear as the first non-whitespace character on a line ...
#   Language python: 7 messages
#     - expected an indented block after function definition on line 1 (43d3a64549ac59f99407b3ceae26bb7c_0.py, line 1) ...
#     - invalid syntax (8fcf0327c63d30b1fa3f7ecf406b6708_0.py, line 2) ...
#     - invalid syntax (c226798ca7e4a129046cd3f79ca1bac0_2.py, line 1) ...
#     - invalid syntax (54898efac9e560442d4563e023b06d40_10.py, line 1) ...
#     - invalid syntax (6780b31e26682462ccae6d27ab20b216_0.py, line 1) ...
#   Language javascript: 7 messages
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token ) ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#     - Parsing error: Unexpected token < ...
#
# Category Overflow Error (21 messages):
#   Language c: 21 messages
#     - expected ',' or ';' before 'c' ...
#     - 'TIM_CCER_CC2P_Pos' undeclared (first use in this function) ...
#     - redefinition of 'fpa' ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before 'if' ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '.' token ...
#
# Category Lifetime Error (10 messages):
#   Language c: 6 messages
#     - unknown type name 'Record' ...
#     - expected ')' before 'r' ...
#     - 'struct spi_transfer' has no member named 'rx_buf' ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '{' token ...
#     - expected '=', ',', ';', 'asm' or '__attribute__' before '-' token ...
#   Language csharp: 3 messages
#     - Type or namespace definition, or end-of-file expected ...
#     - Unexpected character '`' ...
#     - ) expected ...
#   Language python: 1 messages
#     - invalid syntax (36364bae3532b06646b2aa02dfaa232c_3.py, line 1) ...
#
# Category Semantic Error (6 messages):
#   Language c: 6 messages
#     - expected expression before '[' token ...
#     - unknown type name 'vec2' ...
#     - expected identifier or '(' before 'case' ...
#     - expected expression before '>' token ...
#     - expected declaration specifiers or '...' before '&' token ...
#
# Category Memory Error (5 messages):
#   Language c: 5 messages
#     - expected identifier or '(' before '%' token ...
#     - 'struct spi_transfer' has no member named 'tx_buf' ...
#     - 'struct spi_transfer' has no member named 'len' ...
#     - 'struct spi_transfer' has no member named 'rx_buf' ...
#     - 'struct spi_transfer' has no member named 'tx_buf' ...

# %% [markdown]
# ### Clustering (Not using this rn)

# %%
n_clusters = 5  

clustering = MiniBatchKMeans(n_clusters=n_clusters, random_state=42, batch_size=1024)
labels = clustering.fit_predict(embeddings)

# %%
labels
# Out:
# array([1, 1, 1, ..., 2, 2, 3], shape=(177732,), dtype=int32)

# %%
clusters = defaultdict(list)
for label, msg in zip(labels, messages):
    clusters[label].append(msg)

# %%
for cid in range(n_clusters):
    print(f"\nCluster {cid} ({len(clusters[cid])} messages):")
    for m in clusters[cid][:5]:  # preview first 5 per cluster
        print("  -", m.replace("\n", " ")[:120], "...")
# Out:
# Cluster 0 (44985 messages):
#   - Identifier expected ...
#   - Identifier expected ...
#   - Identifier expected ...
#   - Identifier expected ...
#   - Identifier expected ...
#
# Cluster 1 (40757 messages):
#   - The file does not include <?php tag ...
#   - The file does not include <?php tag ...
#   - The file does not include <?php tag ...
#   - The file does not include <?php tag ...
#   - The file does not include <?php tag ...
#
# Cluster 2 (12187 messages):
#   - The modifier 'public' is not valid for this item ...
#   - A namespace cannot directly contain members such as fields, methods or statements ...
#   - The modifier 'private' is not valid for this item ...
#   - Member modifier 'protected' must precede the member type and name ...
#   - The modifier 'public' is not valid for this item ...
#
# Cluster 3 (62712 messages):
#   - Type or namespace definition, or end-of-file expected ...
#   - Type or namespace definition, or end-of-file expected ...
#   - Type or namespace definition, or end-of-file expected ...
#   - Type or namespace definition, or end-of-file expected ...
#   - The namespace alias qualifier '::' always resolves to a type or namespace so is illegal here. Consider using '.' instead ...
#
# Cluster 4 (17091 messages):
#   - ; expected ...
#   - ; expected ...
#   - ; expected ...
#   - ; expected ...
#   - ; expected ...

# %%
from collections import Counter, defaultdict

# Attach labels to rows (messages, symbols, types, etc.)
all_rows = []
i = 0
for key, value in linting_results.items():
    for row in value:
        row_copy = dict(row)  # keep original fields
        row_copy["language"] = key
        row_copy["cluster"] = int(labels[i])  # add cluster label
        all_rows.append(row_copy)
        i += 1

print(f"Total rows with clusters: {len(all_rows)}")

# Group by cluster
clusters = defaultdict(list)
for row in all_rows:
    clusters[row["cluster"]].append(row)

# --- Analysis per cluster ---
for cid, rows in clusters.items():
    print("\n" + "="*60)
    print(f"Cluster {cid} (size={len(rows)})")
    print("="*60)

    # Count messages
    msg_counts = Counter([r["message"] for r in rows if "message" in r])
    print("Top 5 messages:")
    for msg, count in msg_counts.most_common(5):
        print(f"{count:5d}  {msg}")

    # Count symbols
    sym_counts = Counter([r["symbol"] for r in rows if "symbol" in r])
    print("Top symbols:")
    for sym, count in sym_counts.most_common(3):
        print(f"{count:5d}  {sym}")

    # Count types
    type_counts = Counter([r["type"] for r in rows if "type" in r])
    print("Top types:")
    for typ, count in type_counts.most_common(3):
        print(f"{count:5d}  {typ}")

    # Breakdown by language
    lang_counts = Counter([r["language"] for r in rows])
    print("Languages in cluster:")
    for lang, count in lang_counts.most_common():
        print(f"{lang:12s} {count}")
# Out:
# Total rows with clusters: 177732
#
# ============================================================
# Cluster 1 (size=40757)
# ============================================================
# Top 5 messages:
#  9592  Parsing error: Unexpected token <
#  4931  Syntax error, ',' expected
#  4408  Invalid expression term '<'
#  1996  Invalid token ':' in class, record, struct, or interface member declaration
#  1935  The file does not include <?php tag
# Top symbols:
# 38822  syntax-error
#  1935  Not valid php file
# Top types:
# 40757  syntax-error
# Languages in cluster:
# csharp       20112
# javascript   15475
# c            3232
# php          1935
# java         3
#
# ============================================================
# Cluster 4 (size=17091)
# ============================================================
# Top 5 messages:
# 12728  ; expected
#  2568  } expected
#   749  { expected
#   739  ) expected
#   305  Expected expression
# Top symbols:
# 17091  syntax-error
# Top types:
# 17091  syntax-error
# Languages in cluster:
# csharp       17091
#
# ============================================================
# Cluster 3 (size=62712)
# ============================================================
# Top 5 messages:
#  2639  Type or namespace definition, or end-of-file expected
#   846  unknown type name 'CREATE'
#   844  unknown type name 'class'
#   670  stray '#' in program
#   568  Top-level statements must precede namespace and type declarations.
# Top symbols:
# 62712  syntax-error
# Top types:
# 62712  syntax-error
# Languages in cluster:
# c            37198
# python       19805
# csharp       5518
# javascript   144
# java         47
#
# ============================================================
# Cluster 2 (size=12187)
# ============================================================
# Top 5 messages:
#  3059  A get or set accessor expected
#  2144  The modifier 'private' is not valid for this item
#  1466  The modifier 'public' is not valid for this item
#  1297  initializer element is not constant
#   739  A namespace cannot directly contain members such as fields, methods or statements
# Top symbols:
# 12187  syntax-error
# Top types:
# 12187  syntax-error
# Languages in cluster:
# csharp       8875
# c            3199
# javascript   63
# java         50
#
# ============================================================
# Cluster 0 (size=44985)
# ============================================================
# Top 5 messages:
#  6373  expected identifier or '(' before '%' token
#  4662  Identifier expected
#  2484  expected '=', ',', ';', 'asm' or '__attribute__' before '::' token
#  2196  expected declaration specifiers or '...' before numeric constant
#  2011  expected '=', ',', ';', 'asm' or '__attribute__' before '.' token
# Top symbols:
# 44985  syntax-error
# Top types:
# 44985  syntax-error
# Languages in cluster:
# c            39740
# csharp       5202
# javascript   43
